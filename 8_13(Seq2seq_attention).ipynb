# %%
# !pip install konlpy
# Out:
# Collecting konlpy
#   Downloading https://files.pythonhosted.org/packages/85/0e/f385566fec837c0b83f216b2da65db9997b35dd675e107752005b7d392b1/konlpy-0.5.2-py2.py3-none-any.whl (19.4MB)
#      |████████████████████████████████| 19.4MB 66.7MB/s
# Collecting beautifulsoup4==4.6.0
#   Downloading https://files.pythonhosted.org/packages/9e/d4/10f46e5cfac773e22707237bfcd51bbffeaf0a576b0a847ec7ab15bd7ace/beautifulsoup4-4.6.0-py3-none-any.whl (86kB)
#      |████████████████████████████████| 92kB 12.4MB/s
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.6/dist-packages (from konlpy) (1.18.5)
# Collecting tweepy>=3.7.0
#   Downloading https://files.pythonhosted.org/packages/bb/7c/99d51f80f3b77b107ebae2634108717362c059a41384a1810d13e2429a81/tweepy-3.9.0-py2.py3-none-any.whl
# Collecting JPype1>=0.7.0
#   Downloading https://files.pythonhosted.org/packages/8b/f7/a368401e630f0e390dd0e62c39fb928e5b23741b53c2360ee7d376660927/JPype1-1.0.2-cp36-cp36m-manylinux2010_x86_64.whl (3.8MB)
#      |████████████████████████████████| 3.8MB 23.5MB/s
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.6/dist-packages (from konlpy) (4.2.6)
# Collecting colorama
#   Downloading https://files.pythonhosted.org/packages/c9/dc/45cdef1b4d119eb96316b3117e6d5708a08029992b2fee2c143c7a0a5cc5/colorama-0.4.3-py2.py3-none-any.whl
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from JPype1>=0.7.0->konlpy) (3.7.4.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2020.6.20)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# Installing collected packages: beautifulsoup4, tweepy, JPype1, colorama, konlpy
#   Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
#   Found existing installation: tweepy 3.6.0
#     Uninstalling tweepy-3.6.0:
#       Successfully uninstalled tweepy-3.6.0
# Successfully installed JPype1-1.0.2 beautifulsoup4-4.6.0 colorama-0.4.3 konlpy-0.5.2 tweepy-3.9.0

# %%
import tensorflow as tf
import random
from konlpy.tag import Okt #openkorean
#konlpy : 한국어처리, okt는 트위터에서 만든 형태소 분석 패키지

# %%
EPOCHS = 200
NUM_WORDS = 2000

# %% [markdown]
# #Encoder

# %%
class Encoder(tf.keras.Model):
    def __init__(self):
        super(Encoder,self).__init__()
        self.emb = tf.keras.layers.Embedding(NUM_WORDS,64)
        self.lstm = tf.keras.layers.LSTM(512,return_sequences=True,return_state = True) #return state가 들어가야 hidden과 cell state
        #return_sequence = True를해서 모든타임스텝에대한 hidden
    def __call__(self, x, training = False, maks = None):
        x = self.emb(x)
        H, h, c = self.lstm(x)
        return H,h,c

# %% [markdown]
# #Decoder

# %%
class Decoder(tf.keras.Model):
    def __init__(self):
        super(Decoder,self).__init__()
        self.emb = tf.keras.layers.Embedding(NUM_WORDS,64)
        self.lstm = tf.keras.layers.LSTM(512,return_sequences=True,return_state=True)#return_sequence가 true여서 dense에 들어가는게 문장 전체로 들어가게 된다.
        #attension해서 concat
        self.att = tf.keras.layers.Attention()
        self.dense = tf.keras.layers.Dense(NUM_WORDS, activation='softmax')
    
    def __call__(self,inputs, training =False,mask =None):
        y_,s0,c0,H=inputs#shifted output, hidden, cellstate 처음들어오는거, encoder단에서 새로오는거
        y_ = self.emb(y_)
        S,h,c = self.lstm(y_,initial_state=[s0,c0])#맨처음에 encoder에서 나온걸 넣어주고 나머진 shift

        #H는 key,value, S는 query(한 타임스텝앞의것)
        S_ = tf.concat([s0[:,tf.newaxis,:],S[:,:-1,:]],axis = 1)#2차원짜리 s0를 확장
        A = self.att([S_,H])#query,(keyvalue)
        y = tf.concat([S,A],axis = -1)

        return self.dense(y), h, c

# %% [markdown]
# #Seq2seq 모델 정의

# %%
class Seq2seq(tf.keras.Model):
    def __init__(self, sos, eos):
        super(Seq2seq, self).__init__()
        self.enc = Encoder()
        self.dec = Decoder()
        self.sos = sos#start of sequence
        self.eos = eos#end of sequence

    def __call__(self, inputs,training = False, maks = None):
        #autograph
        if training is True:
            x, y =inputs #output을 dec에 shifted 출력을 넣어야 하니까.
            H,h, c = self.enc(x) #hidden 과 cell state를 저장
            y, _, _ = self.dec((y,h,c,H))
            return y #y는 decorder결과라 전체 문장이 된다.

        #shifted 된걸 training에선 feeding하기 때문에 더 쉬운데
        #test땐 마지막 출력을 feeding해야하기 때문에 좀 더 복잡해진다.
        else:
            x = inputs
            H,h, c = self.enc(x) #context계산까진 똑같다.
            y = tf.convert_to_tensor(self.sos)
            y = tf.reshape(y,(1,1))

            seq = tf.TensorArray(tf.int32, 64)#최대 64의 길이로
            #autograph가 됨 tf for문이됨 다 tf로 쓰면
            for idx in tf.range(64):
                y, h, c = self.dec([y,h,c,H])# h,c는 encorder에서 받아온 hidden, cell state다. for 문 을 통해 이전 타임스텝의 값을 shift해서 얻게 된다.
                y = tf.cast(tf.argmax(y, axis = -1),dtype=tf.int32)#one-hot vector로 바꿔준다.sparse하게
                y = tf.reshape(y,(1,1)) #dimension이 하나가 되는데, batch하나의 값이라는 걸 표현하기 위해 고쳐준다.
                seq = seq.write(idx,y)

                if y == self.eos:
                    break
            return tf.reshape(seq.stack(),(1,64))#seq에 만들어둔걸 쌓아두는 작업이다.그리고 (배치,문장 최대길이)로 리쉐이프해서 출력해준다.

# %% [markdown]
# #루프 정의

# %%
@tf.function
def train_step(model,inputs,labels,loss_object,optimizer,train_loss,train_accuracy):
    output_labels = labels[:,1:]#맨앞은 sos라 뺀게 포함이 되고,
    shifted_labels = labels[:,:-1]#학습시 input으로 같이 넣어준다. seq2seq의 y이다. sos포함 eos빠짐. 즉, 오른쪽으로 shift된거
    with tf.GradientTape() as tape:
        predictions = model([inputs,shifted_labels],training = True)
        loss = loss_object(output_labels, predictions)
    gradients = tape.gradient(loss, model.trainable_variables)

    optimizer.apply_gradients(zip(gradients,model.trainable_variables))
    train_loss(loss)
    train_accuracy(output_labels,predictions)
  
@tf.function
def test_step(model,inputs):
    return model(inputs,training = False)#배치하나만 받아서 시퀀스 출력해준다!

# %% [markdown]
# #데이터셋

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
dataset_file = '/content/gdrive/My Drive/Colab Notebooks/aop-딥러닝-인공지능-강의자료/chatbot_data.csv'
okt = Okt()
#질문, 답, 질문, 답으로 이루어짐 카페에서의 문답!
with open(dataset_file, 'r') as file:
    lines = file.readlines()
    seq = [' '.join(okt.morphs(line))for line in lines]#morphs는 한 줄 한줄 형태소 분석해주는거이다.
    #tokenizer에서 space를 기준으로 하기 때문에 ' '에 join을 해서 넣어준다.

questions = seq[::2]#홀수행
answers = ['\t'+lines for lines in seq[1::2]]#첫번째부터 짝수행을 가져온다. 탭의 역할은 start of sequence그리고 \n은 eos

num_sample = len(questions)

perm = list(range(num_sample))
random.seed(0)
random.shuffle(perm)

train_q = list()
train_a = list()

test_q = list()
test_a = list()

for idx, qna in enumerate(zip(questions, answers)):
    q, a = qna
    if perm[idx] > num_sample//5:#80%training, 
        train_q.append(q)
        train_a.append(a)

    else:#20% test
        test_q.append(q)
        test_a.append(a)

tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=NUM_WORDS,filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~')#빈도수가 높은 num_words개수로 토크나이즈

tokenizer.fit_on_texts(train_q+train_a)


#sparse 인코딩된 단어형태
train_q_seq = tokenizer.texts_to_sequences(train_q)
train_a_seq = tokenizer.texts_to_sequences(train_a)

test_q_seq = tokenizer.texts_to_sequences(test_q)
test_a_seq = tokenizer.texts_to_sequences(test_a)

x_train = tf.keras.preprocessing.sequence.pad_sequences(train_q_seq,
                                                        value=0,
                                                        padding='pre',
                                                        maxlen=64)
y_train = tf.keras.preprocessing.sequence.pad_sequences(train_a_seq,
                                                        value=0,
                                                        padding='post',#결과니까 뒤에다가 0으로 padding한다.
                                                        maxlen=65)#맨뒤의 eos는 떼고 사용하니까
x_test = tf.keras.preprocessing.sequence.pad_sequences(test_q_seq,
                                                        value=0,
                                                        padding='pre',
                                                        maxlen=64)
y_test = tf.keras.preprocessing.sequence.pad_sequences(test_a_seq,
                                                        value=0,
                                                        padding='post',
                                                        maxlen=65)

train_ds = tf.data.Dataset.from_tensor_slices((x_train,y_train)).shuffle(10000).batch(32).prefetch(1024)
test_ds = tf.data.Dataset.from_tensor_slices((x_train,y_train)).batch(1).prefetch(1024)

# %% [markdown]
# #학습 환경 정의

# %%
model = Seq2seq(sos = tokenizer.word_index['\t'],#sos
                eos = tokenizer.word_index['\n'])#eos

loss_object = tf.keras.losses.SparseCategoricalCrossentropy()
optimizer = tf.keras.optimizers.Adam()

train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='train_accuracy')

# %%
for epoch in range(EPOCHS):
  for seqs,labels in train_ds:
    train_step(model, seqs, labels, loss_object, optimizer, train_loss, train_accuracy)

  template = 'Epoch:{}, Loss: {}, Accuracy: {}'
  print(template.format(epoch+1,
                        train_loss.result(),
                        train_accuracy.result()*100))
  train_loss.reset_states()
  train_accuracy.reset_states()
# Out:
# Epoch:1, Loss: 2.6630282402038574, Accuracy: 84.4650650024414
# Epoch:2, Loss: 0.5206864476203918, Accuracy: 91.78023529052734
# Epoch:3, Loss: 0.48880404233932495, Accuracy: 92.01127624511719
# Epoch:4, Loss: 0.4724532663822174, Accuracy: 92.15617370605469
# Epoch:5, Loss: 0.4771592915058136, Accuracy: 92.0504379272461
# Epoch:6, Loss: 0.46357032656669617, Accuracy: 92.16008758544922
# Epoch:7, Loss: 0.45518746972084045, Accuracy: 92.1483383178711
# Epoch:8, Loss: 0.44401174783706665, Accuracy: 92.25407409667969
# Epoch:9, Loss: 0.4339218735694885, Accuracy: 92.285400390625
# Epoch:10, Loss: 0.40951743721961975, Accuracy: 92.45378875732422
# Epoch:11, Loss: 0.40366777777671814, Accuracy: 92.94329071044922
# Epoch:12, Loss: 0.3896530866622925, Accuracy: 93.19392395019531
# Epoch:13, Loss: 0.3838551640510559, Accuracy: 93.33098602294922
# Epoch:14, Loss: 0.3718944787979126, Accuracy: 93.42105102539062
# Epoch:15, Loss: 0.36484861373901367, Accuracy: 93.43672180175781
# Epoch:16, Loss: 0.3587966561317444, Accuracy: 93.54244995117188
# Epoch:17, Loss: 0.35915154218673706, Accuracy: 93.48762512207031
# Epoch:18, Loss: 0.346392959356308, Accuracy: 93.64818572998047
# Epoch:19, Loss: 0.34079116582870483, Accuracy: 93.69517517089844
# Epoch:20, Loss: 0.3351227641105652, Accuracy: 93.76566314697266
# Epoch:21, Loss: 0.3292488753795624, Accuracy: 93.8400650024414
# Epoch:22, Loss: 0.32470566034317017, Accuracy: 93.84398651123047
# Epoch:23, Loss: 0.32051923871040344, Accuracy: 93.89881134033203
# Epoch:24, Loss: 0.3138706386089325, Accuracy: 94.00846099853516
# Epoch:25, Loss: 0.30398818850517273, Accuracy: 94.07111358642578
# Epoch:26, Loss: 0.3010251224040985, Accuracy: 94.19251251220703
# Epoch:27, Loss: 0.295166552066803, Accuracy: 94.239501953125
# Epoch:28, Loss: 0.2905654311180115, Accuracy: 94.23167419433594
# Epoch:29, Loss: 0.286289244890213, Accuracy: 94.34915161132812
# Epoch:30, Loss: 0.2793996334075928, Accuracy: 94.40006256103516
# Epoch:31, Loss: 0.2750179171562195, Accuracy: 94.47055053710938
# Epoch:32, Loss: 0.2678757309913635, Accuracy: 94.52928924560547
# Epoch:33, Loss: 0.2628413140773773, Accuracy: 94.55278778076172
# Epoch:34, Loss: 0.2600973844528198, Accuracy: 94.54887390136719
# Epoch:35, Loss: 0.25541213154792786, Accuracy: 94.63502502441406
# Epoch:36, Loss: 0.24726906418800354, Accuracy: 94.65460968017578
# Epoch:37, Loss: 0.24401435256004333, Accuracy: 94.70943450927734
# Epoch:38, Loss: 0.2437233328819275, Accuracy: 94.74859619140625
# Epoch:39, Loss: 0.23840604722499847, Accuracy: 94.86607360839844
# Epoch:40, Loss: 0.22790446877479553, Accuracy: 94.9130630493164
# Epoch:41, Loss: 0.2231140434741974, Accuracy: 94.95613861083984
# Epoch:42, Loss: 0.22071075439453125, Accuracy: 94.96397399902344
# Epoch:43, Loss: 0.21181105077266693, Accuracy: 95.2067642211914
# Epoch:44, Loss: 0.20757317543029785, Accuracy: 95.19502258300781
# Epoch:45, Loss: 0.20310615003108978, Accuracy: 95.36341094970703
# Epoch:46, Loss: 0.20025300979614258, Accuracy: 95.46131134033203
# Epoch:47, Loss: 0.19239841401576996, Accuracy: 95.58662414550781
# Epoch:48, Loss: 0.1882493793964386, Accuracy: 95.64927673339844
# Epoch:49, Loss: 0.17828920483589172, Accuracy: 95.8411636352539
# Epoch:50, Loss: 0.17447516322135925, Accuracy: 96.01346588134766
# Epoch:51, Loss: 0.16972215473651886, Accuracy: 96.14662170410156
# Epoch:52, Loss: 0.16308709979057312, Accuracy: 96.35025024414062
# Epoch:53, Loss: 0.1570480614900589, Accuracy: 96.3385009765625
# Epoch:54, Loss: 0.15445634722709656, Accuracy: 96.43248748779297
# Epoch:55, Loss: 0.14872311055660248, Accuracy: 96.67919921875
# Epoch:56, Loss: 0.14349046349525452, Accuracy: 96.79276275634766
# Epoch:57, Loss: 0.13937053084373474, Accuracy: 96.8671646118164
# Epoch:58, Loss: 0.13193126022815704, Accuracy: 97.09821319580078
# Epoch:59, Loss: 0.12611578404903412, Accuracy: 97.20002746582031
# Epoch:60, Loss: 0.12094402313232422, Accuracy: 97.32926177978516
# Epoch:61, Loss: 0.11797753721475601, Accuracy: 97.42716217041016
# Epoch:62, Loss: 0.1117083951830864, Accuracy: 97.57596588134766
# Epoch:63, Loss: 0.10606260597705841, Accuracy: 97.68953704833984
# Epoch:64, Loss: 0.10117340832948685, Accuracy: 97.85792541503906
# Epoch:65, Loss: 0.09721532464027405, Accuracy: 97.95582580566406
# Epoch:66, Loss: 0.09339268505573273, Accuracy: 98.07722473144531
# Epoch:67, Loss: 0.08809541165828705, Accuracy: 98.17512512207031
# Epoch:68, Loss: 0.08399942517280579, Accuracy: 98.30435180664062
# Epoch:69, Loss: 0.08054293692111969, Accuracy: 98.41008758544922
# Epoch:70, Loss: 0.07574920356273651, Accuracy: 98.54714965820312
# Epoch:71, Loss: 0.07046426087617874, Accuracy: 98.64505004882812
# Epoch:72, Loss: 0.06891088932752609, Accuracy: 98.69596099853516
# Epoch:73, Loss: 0.06439720094203949, Accuracy: 98.83301544189453
# Epoch:74, Loss: 0.06188839673995972, Accuracy: 98.86434936523438
# Epoch:75, Loss: 0.059670306742191315, Accuracy: 98.98182678222656
# Epoch:76, Loss: 0.05637529119849205, Accuracy: 98.99748992919922
# Epoch:77, Loss: 0.05264653265476227, Accuracy: 99.13846588134766
# Epoch:78, Loss: 0.05016948655247688, Accuracy: 99.18546295166016
# Epoch:79, Loss: 0.04714902490377426, Accuracy: 99.22462463378906
# Epoch:80, Loss: 0.04568541422486305, Accuracy: 99.28337097167969
# Epoch:81, Loss: 0.04435277357697487, Accuracy: 99.2677001953125
# Epoch:82, Loss: 0.04195857793092728, Accuracy: 99.36952209472656
# Epoch:83, Loss: 0.038937926292419434, Accuracy: 99.41651153564453
# Epoch:84, Loss: 0.03627073019742966, Accuracy: 99.43217468261719
# Epoch:85, Loss: 0.034412480890750885, Accuracy: 99.47917175292969
# Epoch:86, Loss: 0.03289337456226349, Accuracy: 99.51441192626953
# Epoch:87, Loss: 0.03081442601978779, Accuracy: 99.58098602294922
# Epoch:88, Loss: 0.0292376559227705, Accuracy: 99.62406158447266
# Epoch:89, Loss: 0.027525050565600395, Accuracy: 99.6005630493164
# Epoch:90, Loss: 0.02576308324933052, Accuracy: 99.63972473144531
# Epoch:91, Loss: 0.025217212736606598, Accuracy: 99.66322326660156
# Epoch:92, Loss: 0.023886123672127724, Accuracy: 99.68280029296875
# Epoch:93, Loss: 0.0228686835616827, Accuracy: 99.71804809570312
# Epoch:94, Loss: 0.021887149661779404, Accuracy: 99.72587585449219
# Epoch:95, Loss: 0.020232347771525383, Accuracy: 99.72196197509766
# Epoch:96, Loss: 0.019574156031012535, Accuracy: 99.78070068359375
# Epoch:97, Loss: 0.018769407644867897, Accuracy: 99.76895141601562
# Epoch:98, Loss: 0.01828637532889843, Accuracy: 99.76112365722656
# Epoch:99, Loss: 0.01721232756972313, Accuracy: 99.7963638305664
# Epoch:100, Loss: 0.016549279913306236, Accuracy: 99.79244995117188
# Epoch:101, Loss: 0.015743253752589226, Accuracy: 99.82377624511719
# Epoch:102, Loss: 0.015343612059950829, Accuracy: 99.82769775390625
# Epoch:103, Loss: 0.015321786515414715, Accuracy: 99.80028533935547
# Epoch:104, Loss: 0.014106503687798977, Accuracy: 99.84727478027344
# Epoch:105, Loss: 0.014049327932298183, Accuracy: 99.83161163330078
# Epoch:106, Loss: 0.013605883345007896, Accuracy: 99.85511016845703
# Epoch:107, Loss: 0.013898665085434914, Accuracy: 99.85118865966797
# Epoch:108, Loss: 0.013566642068326473, Accuracy: 99.84727478027344
# Epoch:109, Loss: 0.012392591685056686, Accuracy: 99.87860107421875
# Epoch:110, Loss: 0.011735627427697182, Accuracy: 99.87860107421875
# Epoch:111, Loss: 0.011288976296782494, Accuracy: 99.89035034179688
# Epoch:112, Loss: 0.01048301812261343, Accuracy: 99.89818572998047
# Epoch:113, Loss: 0.009856035932898521, Accuracy: 99.90601348876953
# Epoch:114, Loss: 0.009290228597819805, Accuracy: 99.90601348876953
# Epoch:115, Loss: 0.009012953378260136, Accuracy: 99.90601348876953
# Epoch:116, Loss: 0.00867941603064537, Accuracy: 99.9099349975586
# Epoch:117, Loss: 0.008378800936043262, Accuracy: 99.92951202392578
# Epoch:118, Loss: 0.007808880880475044, Accuracy: 99.93342590332031
# Epoch:119, Loss: 0.007680704817175865, Accuracy: 99.93734741210938
# Epoch:120, Loss: 0.007244729436933994, Accuracy: 99.95301055908203
# Epoch:121, Loss: 0.007126699201762676, Accuracy: 99.95301055908203
# Epoch:122, Loss: 0.00688472855836153, Accuracy: 99.95692443847656
# Epoch:123, Loss: 0.006610848009586334, Accuracy: 99.94517517089844
# Epoch:124, Loss: 0.006347904447466135, Accuracy: 99.94908905029297
# Epoch:125, Loss: 0.006538549438118935, Accuracy: 99.93734741210938
# Epoch:126, Loss: 0.009386071003973484, Accuracy: 99.87468719482422
# Epoch:127, Loss: 0.010282953269779682, Accuracy: 99.8942642211914
# Epoch:128, Loss: 0.008689711801707745, Accuracy: 99.91776275634766
# Epoch:129, Loss: 0.007563354447484016, Accuracy: 99.9412612915039
# Epoch:130, Loss: 0.006153570953756571, Accuracy: 99.9608383178711
# Epoch:131, Loss: 0.006011249963194132, Accuracy: 99.95301055908203
# Epoch:132, Loss: 0.0054649775847792625, Accuracy: 99.95692443847656
# Epoch:133, Loss: 0.004944037180393934, Accuracy: 99.96475219726562
# Epoch:134, Loss: 0.00481238029897213, Accuracy: 99.9608383178711
# Epoch:135, Loss: 0.004706884268671274, Accuracy: 99.9608383178711
# Epoch:136, Loss: 0.004555955063551664, Accuracy: 99.96475219726562
# Epoch:137, Loss: 0.004265653435140848, Accuracy: 99.96475219726562
# Epoch:138, Loss: 0.0041360268369317055, Accuracy: 99.96475219726562
# Epoch:139, Loss: 0.003946967888623476, Accuracy: 99.97258758544922
# Epoch:140, Loss: 0.0038624468725174665, Accuracy: 99.97650146484375
# Epoch:141, Loss: 0.0038010997232049704, Accuracy: 99.96867370605469
# Epoch:142, Loss: 0.003797339741140604, Accuracy: 99.97258758544922
# Epoch:143, Loss: 0.0037656486965715885, Accuracy: 99.97258758544922
# Epoch:144, Loss: 0.0036684279330074787, Accuracy: 99.97650146484375
# Epoch:145, Loss: 0.003568852785974741, Accuracy: 99.97650146484375
# Epoch:146, Loss: 0.003413011319935322, Accuracy: 99.97650146484375
# Epoch:147, Loss: 0.0032375638838857412, Accuracy: 99.97258758544922
# Epoch:148, Loss: 0.003241652389988303, Accuracy: 99.97650146484375
# Epoch:149, Loss: 0.0030923662707209587, Accuracy: 99.97258758544922
# Epoch:150, Loss: 0.003122033318504691, Accuracy: 99.96867370605469
# Epoch:151, Loss: 0.0029015245381742716, Accuracy: 99.96867370605469
# Epoch:152, Loss: 0.0029120519757270813, Accuracy: 99.97258758544922
# Epoch:153, Loss: 0.0028747941832989454, Accuracy: 99.97258758544922
# Epoch:154, Loss: 0.002875437494367361, Accuracy: 99.96867370605469
# Epoch:155, Loss: 0.0027735158801078796, Accuracy: 99.97258758544922
# Epoch:156, Loss: 0.0027828002348542213, Accuracy: 99.97258758544922
# Epoch:157, Loss: 0.0027430146001279354, Accuracy: 99.98042297363281
# Epoch:158, Loss: 0.0026389982085675, Accuracy: 99.97650146484375
# Epoch:159, Loss: 0.0025101504288613796, Accuracy: 99.97650146484375
# Epoch:160, Loss: 0.0024572391994297504, Accuracy: 99.97258758544922
# Epoch:161, Loss: 0.002414979273453355, Accuracy: 99.97650146484375
# Epoch:162, Loss: 0.0026177505496889353, Accuracy: 99.96867370605469
# Epoch:163, Loss: 0.0024759795051068068, Accuracy: 99.97650146484375
# Epoch:164, Loss: 0.0023413775488734245, Accuracy: 99.97258758544922
# Epoch:165, Loss: 0.002273228717967868, Accuracy: 99.97650146484375
# Epoch:166, Loss: 0.0022271261550486088, Accuracy: 99.96475219726562
# Epoch:167, Loss: 0.0021771166939288378, Accuracy: 99.97258758544922
# Epoch:168, Loss: 0.0021337876096367836, Accuracy: 99.97258758544922
# Epoch:169, Loss: 0.002218651119619608, Accuracy: 99.97258758544922
# Epoch:170, Loss: 0.00211098650470376, Accuracy: 99.98042297363281
# Epoch:171, Loss: 0.002097797580063343, Accuracy: 99.96867370605469
# Epoch:172, Loss: 0.0020917090587317944, Accuracy: 99.97650146484375
# Epoch:173, Loss: 0.0019805484917014837, Accuracy: 99.97650146484375
# Epoch:174, Loss: 0.002053030300885439, Accuracy: 99.97650146484375
# Epoch:175, Loss: 0.002037050435319543, Accuracy: 99.97650146484375
# Epoch:176, Loss: 0.0020067307632416487, Accuracy: 99.97258758544922
# Epoch:177, Loss: 0.0020262012258172035, Accuracy: 99.97650146484375
# Epoch:178, Loss: 0.0018746816786006093, Accuracy: 99.97650146484375
# Epoch:179, Loss: 0.001846184954047203, Accuracy: 99.97258758544922
# Epoch:180, Loss: 0.0018285287078469992, Accuracy: 99.97258758544922
# Epoch:181, Loss: 0.0017833844758570194, Accuracy: 99.97650146484375
# Epoch:182, Loss: 0.0017452612519264221, Accuracy: 99.96867370605469
# Epoch:183, Loss: 0.0017002890817821026, Accuracy: 99.96867370605469
# Epoch:184, Loss: 0.0016818142030388117, Accuracy: 99.97650146484375
# Epoch:185, Loss: 0.0017402791418135166, Accuracy: 99.96475219726562
# Epoch:186, Loss: 0.0017017328646034002, Accuracy: 99.97258758544922
# Epoch:187, Loss: 0.0016986634582281113, Accuracy: 99.98042297363281
# Epoch:188, Loss: 0.001778802485205233, Accuracy: 99.97650146484375
# Epoch:189, Loss: 0.0017932503251358867, Accuracy: 99.98042297363281
# Epoch:190, Loss: 0.0015735137276351452, Accuracy: 99.97258758544922
# Epoch:191, Loss: 0.0017006616108119488, Accuracy: 99.97258758544922
# Epoch:192, Loss: 0.0016081004869192839, Accuracy: 99.98042297363281
# Epoch:193, Loss: 0.001586891827173531, Accuracy: 99.97258758544922
# Epoch:194, Loss: 0.0017017137724906206, Accuracy: 99.97258758544922
# Epoch:195, Loss: 0.0015724635450169444, Accuracy: 99.98042297363281
# Epoch:196, Loss: 0.0015964563935995102, Accuracy: 99.97258758544922
# Epoch:197, Loss: 0.001511282753199339, Accuracy: 99.97650146484375
# Epoch:198, Loss: 0.0015337246004492044, Accuracy: 99.97650146484375
# Epoch:199, Loss: 0.001531782210804522, Accuracy: 99.97258758544922
# Epoch:200, Loss: 0.0014400363434106112, Accuracy: 99.98042297363281

# %%
for test_seq, test_labels in test_ds:
    prediction = test_step(model, test_seq)
    test_text = tokenizer.sequences_to_texts(test_seq.numpy())
    gt_text = tokenizer.sequences_to_texts(test_labels.numpy())
    texts = tokenizer.sequences_to_texts(prediction.numpy())
    print('_')
    print('q:',test_text)#input
    print('a:',gt_text)#정답
    print('p:',texts)#예측한 답변
# Out:
# _
# q: ['아이스 아메리카노 하나요 \n']
# a: ['\t테이크아웃 하실 건가 요 \n']
# p: ['네 저희 가게 마스코트 메뉴 에요 \n']
# _
# q: ['저 카푸치노 로 주문 할게요 \n']
# a: ['\t시럽 은 얼마나 뿌려 드릴 까요 \n']
# p: ['네 알겠습니다 \n']
# _
# q: ['저 도장 다 모았는데 나중 에 써도 되나요 \n']
# a: ['\t네 다음 에 써도 됩니다 \n']
# p: ['쪽 한 사이즈 로만 판매 하고 있습니다 \n']
# _
# q: ['이 기프티콘 여기 서 사용 할 수 있나요 \n']
# a: ['\t사용 가능하십니다 \n']
# p: ['네 같이 적립 해 드리겠습니다 \n']
# _
# q: ['자바 칩 프라푸치노 에 휘핑 빼고요 \n']
# a: ['\t6600원 입니다 \n']
# p: ['아뇨 매장 에서는 로만 있습니다 \n']
# _
# q: ['따뜻한 아메리카노 한 잔 아이스 라떼 한 잔이요 \n']
# a: ['\t드시고 가시나요 \n']
# p: ['네 뜨거운 음료 로 드릴 까요 \n']
# _
# q: ['네 스콘 도 3 개 같이 주세요 \n']
# a: ['\t스콘 도 드시고 가시나요 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['카푸치노 차갑게 되나요 \n']
# a: ['\t가능합니다 \n']
# p: ['아니요 한 사이즈 로만 판매 하고 있습니다 \n']
# _
# q: ['아이스 카푸치노 개인 컵 에 주실 수 있나요 \n']
# a: ['\t개인 컵 사이즈 가 작아서 음료 가 다 안 들어가요 \n']
# p: ['네 같이 적립 해 드리겠습니다 \n']
# _
# q: ['음료 와 같이 먹을 빵 추천 해주세요 \n']
# a: ['\t호두 베이글 이 잘 어울려요 \n']
# p: ['네 담아 드립니다 \n']
# _
# q: ['모바일 쿠폰 으로 결제 할 수 있어요 \n']
# a: ['\t네 가능해요 \n']
# p: ['네 같이 적립 해 드리겠습니다 \n']
# _
# q: ['화장실 은 어디 에 있나요 \n']
# a: ['\t오른쪽 벽쪽 으로 있어요 \n']
# p: ['네 500원 할인 하시면 있습니다 \n']
# _
# q: ['여기 에서 제일 잘나가는 커피 가 뭐 에요 \n']
# a: ['\t요새 는 이 라이트 한 맛 의 아이스 아메리카노 가 제일 잘나가요 \n']
# p: ['네 담아 드립니다 \n']
# _
# q: ['라이트 한 맛 의 아이스 아메리카노 요 \n']
# a: ['\t 네 저희 가게 마스코트 메뉴 에요 \n']
# p: ['네 저희 가게 마스코트 메뉴 에요 \n']
# _
# q: ['쿠폰 찍어주세요 \n']
# a: ['\t10 개 다모아 오시 면 커피한잔 드려요 \n']
# p: ['네 저희 가게 마스코트 메뉴 에요 \n']
# _
# q: ['네 그리고 이 맴버쉽 할인 사용 할게요 \n']
# a: ['\t네 드시고 가시나요 \n']
# p: ['네 드시고 가시나요 \n']
# _
# q: ['와이파이 비밀번호 는 뭐 에요 \n']
# a: ['\t영수증 하단 에 적혀있습니다 \n']
# p: ['네 가능합니다 \n']
# _
# q: ['계절 메뉴 주문 가능한가요 \n']
# a: ['\t 네 가능합니다 \n']
# p: ['네 가능합니다 \n']
# _
# q: ['배달 하시나요 \n']
# a: ['\t 네 배달 비 3000원 입니다 \n']
# p: ['네 배달 비 3000원 입니다 \n']
# _
# q: ['커피 에 샷 추가 가능한가요 \n']
# a: ['\t 네 가능합니다 \n']
# p: ['네 가능합니다 \n']
# _
# q: ['남은 음료 담아 주시나요 \n']
# a: ['\t 네 담아 드립니다 \n']
# p: ['네 담아 드립니다 \n']
# _
# q: ['밀크 티 있나요 \n']
# a: ['\t네 있습니다 \n']
# p: ['아니요 한 사이즈 로만 판매 하고 있습니다 \n']
# _
# q: ['밀크 티 에 혹시 우유 가 들어가나요 아니면 우유 분말 이 들어가나요 \n']
# a: ['\t저희 는 우유 분말 을 사용 하고 있어요 \n']
# p: ['네 사이즈 는 블랙 분말 을 이 있습니다 \n']
# _
# q: ['밀크 티 홍차 종류 는 뭐 가 있어요 \n']
# a: ['\t 루이보스 아쌈 이렇게 두 개 있습니다 \n']
# p: ['루이보스 아쌈 이렇게 두 개 있습니다 \n']
# _
# q: ['쿠폰 주시나요 \n']
# a: ['\t네 드릴게요 잠시 만 요 \n']
# p: ['네 배달 비 3000원 입니다 \n']
# _
# q: ['아이스 아메리카노 한잔 이 요 \n']
# a: ['\t드시고 가시는거세요 \n']
# p: ['네 어떤 거 로 드릴 까요 \n']
# _
# q: ['텀블러 가져왔는데 여기 에 담아주세요 \n']
# a: ['\t알겠습니다 \n']
# p: ['네 같이 적립 해 드리겠습니다 \n']
# _
# q: ['2 명 창가 자리 에 앉을 수 있을까요 \n']
# a: ['\t네 기다리시면 안내 해드릴게요 \n']
# p: ['네 티 는 블랙 드리겠습니다 \n']
# _
# q: ['저 는 우선 따뜻한 물이 랑 커피 주세요 \n']
# a: ['\t커피 는 시럽 은 넣어 드릴 까요 \n']
# p: ['네 더 필요한 거 있으세요 \n']
# _
# q: ['혹시 빵 종류 도 있나요 \n']
# a: ['\t네 저기 서 직접 가져오시면 됩니다 \n']
# p: ['네 가능합니다 \n']
# _
# q: ['사이즈 업 되나요 \n']
# a: ['\t네 가능합니다 \n']
# p: ['아니요 한 사이즈 로만 판매 하고 있습니다 \n']
# _
# q: ['카푸치노 한잔 이랑 아메리카노 두 잔 주세요 \n']
# a: ['\t 네 뜨거운 음료 로 드릴 까요 \n']
# p: ['네 뜨거운 음료 로 드릴 까요 \n']
# _
# q: ['얼마나 걸릴까 요 \n']
# a: ['\t대략 5분 정도 걸립니다 \n']
# p: ['네 저희 가게 마스코트 메뉴 에요 \n']
# _
# q: ['음료 랑 다 해서 얼마 에요 \n']
# a: ['\t 14 500원 입니다 \n']
# p: ['14 500원 입니다 \n']
# _
# q: ['죄송한데 조각 케이크 도 추가 해주시겠어요 \n']
# a: ['\t 네 어떤 거 로 드릴 까요 \n']
# p: ['네 어떤 거 로 드릴 까요 \n']
# _
# q: ['아메리카노 한잔 주세요 \n']
# a: ['\t드시고 가시나요 \n']
# p: ['네 드시고 가시나요 \n']
# _
# q: ['네 텀블러 에 담아주실 수 있나요 \n']
# a: ['\t네 그럼요 \n']
# p: ['네 같이 적립 해 드리겠습니다 \n']
# _
# q: ['텀블러 할인 있나요 \n']
# a: ['\t네 500원 할인 되세요 \n']
# p: ['네 500원 가능합니다 \n']
# _
# q: ['치즈 케익 도 하나 주세요 \n']
# a: ['\t네 결제 도 와 드릴게요 \n']
# p: ['네 더 더 카드 있으세요 \n']
# _
# q: ['삼성 페이 되나요 \n']
# a: ['\t네 가능하세요 \n']
# p: ['아니요 한 사이즈 로만 판매 하고 됩니다 \n']
# _
# q: ['아메리카노 한잔 주문 할 수 있을까요 \n']
# a: ['\t 네 주문 가능합니다 \n']
# p: ['네 주문 가능합니다 \n']
# _
# q: ['디카 페인 으로 한잔 주문 할게요 \n']
# a: ['\t결제 는 어떻게 도 와 드릴 까요 \n']
# p: ['네 알겠습니다 \n']
# _
# q: ['포인트 적립 같이 할 수 있나요 \n']
# a: ['\t 네 같이 적립 해 드리겠습니다 \n']
# p: ['네 같이 적립 해 드리겠습니다 \n']
# _
# q: ['커피 주문 할게요 \n']
# a: ['\t네 어떤 걸 로 하시겠습니까 \n']
# p: ['네 어떤 거 로 드릴 까요 \n']
# _
# q: ['네 오늘 의 커피 로 주세요 \n']
# a: ['\t네 사이즈 는 어떤 걸 로 주문 넣어 드릴 까요 \n']
# p: ['네 사이즈 는 어떤 걸 로 주문 넣어 드릴 까요 \n']
# _
# q: ['아 네 제일 양 이 적은 숏 으로 할게요 \n']
# a: ['\t아 네 알겠습니다 \n']
# p: ['네 알겠습니다 \n']
# _
# q: ['아 네 제 가 젤 좋아하는 커피 인데 요 \n']
# a: ['\t오늘 딱 맞게 오셨네요 \n']
# p: ['네 알겠습니다 \n']
# _
# q: ['페퍼민트 티 하나 주세요 \n']
# a: ['\t따뜻한 것 으로 드릴가요 \n']
# p: ['네 더 카드 카드 있으세요 \n']
# _
# q: ['사이즈 업 되나요 \n']
# a: ['\t 아니요 한 사이즈 로만 판매 하고 있습니다 \n']
# p: ['아니요 한 사이즈 로만 판매 하고 있습니다 \n']
# _
# q: ['그럼 블루베리 머핀 도 같이 주세요 \n']
# a: ['\t 네 더 필요한 거 없으신 가요 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['주문 하려고 해 요 \n']
# a: ['\t네 손님 메뉴 는 어떻게 드릴 까요 \n']
# p: ['10시 까지 합니다 \n']
# _
# q: ['아이스 아메리카노 랑 따뜻한 라떼 로 주세요 \n']
# a: ['\t사이즈 는 어떻게 드릴 까요 \n']
# p: ['네 뜨거운 음료 로 드릴 까요 \n']
# _
# q: ['아아 주문 가능한가요 \n']
# a: ['\t네 당연히 가능합니다 \n']
# p: ['네 가능합니다 \n']
# _
# q: ['언제 음료 가 나오나요 \n']
# a: ['\t10분 내 로 나갑니다 \n']
# p: ['네 저희 가게 마스코트 메뉴 에요 \n']
# _
# q: ['혹시 아이리쉬 커피 도 판매 하나요 \n']
# a: ['\t아니요 아이리쉬 커피 는 판매 하지 않습니다 \n']
# p: ['네 가능합니다 \n']
# _
# q: ['캐리어 에 넣어 주실 수 있나요 \n']
# a: ['\t아뇨 캐리어 는 2 개 이상 부터 가능해요 \n']
# p: ['네 같이 적립 해 드리겠습니다 \n']
# _
# q: ['실내 에서 일회용 사용 가능한가요 \n']
# a: ['\t아뇨 현재 법적 으로 금지 하고 있어요 \n']
# p: ['네 담아 드립니다 \n']
# _
# q: ['한 사람 당 한잔 씩 시켜야 하나요 \n']
# a: ['\t저희 매장 은 1 인 1 잔 이 기본 입니다 \n']
# p: ['네 매장 가능합니다 \n']
# _
# q: ['쿠키 프라 페 에 휘핑 들어가있나요 \n']
# a: ['\t들어가있습니다 \n']
# p: ['쪽 한 사이즈 로만 판매 하고 있습니다 \n']
# _
# q: ['휘핑 빼주실 수 있나요 \n']
# a: ['\t당연하죠 \n']
# p: ['네 같이 적립 해 드리겠습니다 \n']
# _
# q: ['그러면 아메리카노 하나 랑 쿠키 프라 페 휘핑빼 고 하나 주세요 \n']
# a: ['\t아메리카노 뜨거운건 가요 \n']
# p: ['네 더 필요한 는 것 사이즈 사용 해 도 는 선택 해 하세요 \n']
# _
# q: ['아이스 로 주세요 \n']
# a: ['\t지금 은 아이스 가 안됩니다 \n']
# p: ['네 드시고 가시나요 \n']
# _
# q: ['아메리카노 주세요 \n']
# a: ['\t따듯 하게 드릴 까요 \n']
# p: ['네 드시고 가시나요 \n']
# _
# q: ['차갑게 주세요 \n']
# a: ['\t4천원 입니다 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['허니 브레드 는 얼마 에요 \n']
# a: ['\t7천원 입니다 \n']
# p: ['14 500원 입니다 \n']
# _
# q: ['얼마나 걸려요 \n']
# a: ['\t10분 정도 걸려요 \n']
# p: ['네 배달 비 마스코트 메뉴 에요 \n']
# _
# q: ['포장 도 되나요 \n']
# a: ['\t네 \n']
# p: ['네 가능합니다 \n']
# _
# q: ['헤이즐넛 시럽 도 조금 넣어 주실 수 있나요 \n']
# a: ['\t헤이즐넛 시럽 은 500원 추가 됩니다 \n']
# p: ['네 가능합니다 \n']
# _
# q: ['그럼 사이즈 업은 얼마 추가 인가요 \n']
# a: ['\t500원 추가 하면 가능합니다 \n']
# p: ['네 가능합니다 \n']
# _
# q: ['포인트 적립 해 주세요 \n']
# a: ['\t쿠폰 주시 면 도 와 드리겠습니다 \n']
# p: ['네 사이즈 는 어떤 걸 로 하시겠어요 \n']
# _
# q: ['매장 에서 테이크아웃 잔 사용 가능한가요 \n']
# a: ['\t 아뇨 매장 에서는 머그컵 만 사용 가능합니다 \n']
# p: ['아뇨 매장 에서는 머그컵 만 사용 가능합니다 \n']
# _
# q: ['카페라테 한 잔 주세요 \n']
# a: ['\t네 카페라떼 컵 사이즈 는 뭘 로 드릴 까요 \n']
# p: ['네 뜨거운 음료 로 드릴 까요 \n']
# _
# q: ['카페라떼 제일 큰 사이즈 로 주세요 \n']
# a: ['\t네 그럼 카페라떼 톨 사이즈 로 드리겠습니다 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['베이글 도 하나 부탁드려요 \n']
# a: ['\t베이글 크림 은 어떤 걸 로 드릴 까요 \n']
# p: ['네 가능합니다 \n']
# _
# q: ['베이글 크림 은 어떤 게 있나요 \n']
# a: ['\t어니언 크림 이랑 플레인 크림 있습니다 \n']
# p: ['아니요 한 가능합니다 \n']
# _
# q: ['어니언 크림 으로 부탁드릴게요 \n']
# a: ['\t네 준비 해드리겠습니다 \n']
# p: ['네 어떤 거 로 드릴 까요 \n']
# _
# q: ['아이스 아메리카노 한 잔 주세요 \n']
# a: ['\t아이스 아메리카노 포장 이신 가요 \n']
# p: ['네 뜨거운 음료 로 드릴 까요 \n']
# _
# q: ['아니요 매장 에서 먹을게요 \n']
# a: ['\t머그잔 으로 제공 해드려도 괜찮을까요 \n']
# p: ['네 담아 드립니다 \n']
# _
# q: ['네 여기 오천 원 이요 \n']
# a: ['\t현금영수증 필요하세요 \n']
# p: ['네 저희 가게 거 면 머그컵 사용 드리도록 되어있습니다 \n']
# _
# q: ['아니요 현금영수증 괜찮아요 \n']
# a: ['\t진동 벨 울리면 찾으러 오시 면 됩니다 \n']
# p: ['네 주문 가능합니다 \n']
# _
# q: ['음료 사이즈 업 가능한가요 \n']
# a: ['\t네 가능합니다 \n']
# p: ['아니요 한 사이즈 로만 판매 하고 있습니다 \n']
# _
# q: ['아이스 아메리카노 사이즈 업 해주세요 \n']
# a: ['\t아이스 아메리카노 4000원 입니다 \n']
# p: ['아니요 가능합니다 \n']
# _
# q: ['아메리카노 한 잔 주세요 \n']
# a: ['\t네 아메리카노 어떤 걸 로 드릴 까요 \n']
# p: ['네 뜨거운 음료 로 드릴 까요 \n']
# _
# q: ['아이스 아메리카노 요 \n']
# a: ['\t네 아이스 아메리카노 로 한 잔 드릴게요 \n']
# p: ['네 저희 가게 마스코트 메뉴 에요 \n']
# _
# q: ['음료 한 잔 더 추가 되나요 \n']
# a: ['\t네 말씀 하세요 \n']
# p: ['아뇨 말씀 하세요 \n']
# _
# q: ['바닐라 라테 도 하나 주세요 \n']
# a: ['\t바닐라 라테 따뜻한 거 요 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['네 바닐라 라테 따뜻한 걸 로 주세요 \n']
# a: ['\t네 알겠습니다 \n']
# p: ['네 뜨거운 음료 로 드릴 까요 \n']
# _
# q: ['네 카페라테 디카 페인 되나요 \n']
# a: ['\t네 카페라테 디카 페인 500원 추가 됩니다 \n']
# p: ['아뇨 말씀 2000원 입니다 \n']
# _
# q: ['네 카페라테 디카 페인 으로 주세요 \n']
# a: ['\t진동 벨 이 울리면 받으러 오세요 \n']
# p: ['네 뜨거운 음료 로 드릴 까요 \n']
# _
# q: ['네 감사합니다 \n']
# a: ['\t따뜻한 카페라테 한 잔 나왔습니다 \n']
# p: ['네 가능합니다 \n']
# _
# q: ['카페라테 디카 페인 맞나요 \n']
# a: ['\t네 맛있게 드세요 \n']
# p: ['네 맛있게 필요한 건가 요 \n']
# _
# q: ['자몽 에 이드 한 잔 얼마 에요 \n']
# a: ['\t6000원 이에요 \n']
# p: ['네 가능합니다 \n']
# _
# q: ['자몽 에 이드 사이즈 업 되나요 \n']
# a: ['\t네 자몽 에 이드 사이즈 업 가능해요 \n']
# p: ['아니요 한 사이즈 로만 판매 하고 있습니다 \n']
# _
# q: ['생크림 케이크 는 뭐 가 제일 맛있어요 \n']
# a: ['\t과일 생크림 케이크 가 잘 나가요 \n']
# p: ['네 가능합니다 \n']
# _
# q: ['자몽 에 이드 랑 과일 생크림 케이크 주세요 \n']
# a: ['\t드시고 가시나요 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['포장 가능하죠 \n']
# a: ['\t네 준비 해드릴게요 \n']
# p: ['네 어떤 거 로 드릴 까요 \n']
# _
# q: ['아이스 프라푸치노 주세요 \n']
# a: ['\t네 아이스 프라푸치노 몇 잔 드릴 까요 \n']
# p: ['네 뜨거운 음료 로 드릴 까요 \n']
# _
# q: ['아이스 프라푸치노 한 잔이요 \n']
# a: ['\t아이스 프라푸치노 사이즈 는 어떻게 드릴 까요 \n']
# p: ['네 드시고 가시나요 \n']
# _
# q: ['아이스 프라푸치노 그란 데 사이 즈 로 요 \n']
# a: ['\t아이스 프라푸치노 에 휘핑크림 올려 드릴 까요 \n']
# p: ['네 어떤 거 로 드릴 까요 \n']
# _
# q: ['새벽 에도 영업 해요 \n']
# a: ['\t24시간 영업 하고 있어요 \n']
# p: ['네 담아 드립니다 \n']
# _
# q: ['아메리카노 한 잔 주세요 \n']
# a: ['\t음료 사이즈 말씀 해주세요 \n']
# p: ['네 뜨거운 음료 로 드릴 까요 \n']
# _
# q: ['아메리카노 라지 사이즈 요 \n']
# a: ['\t추가 하실 건 없으세요 \n']
# p: ['네 저희 거 거 만 없으신 \n']
# _
# q: ['네 화장실 은 어디 에요 \n']
# a: ['\t화장실 은 복도 로 나가시 면 보여요 \n']
# p: ['네 가능합니다 \n']
# _
# q: ['와이파이 비밀번호 는 뭐 예요 \n']
# a: ['\t와이파이 비밀번호 는 종이 에 써져있습니다 \n']
# p: ['네 담아 드립니다 \n']
# _
# q: ['딸기 스무디 되나요 \n']
# a: ['\t지금 은 재료 가 다 떨어져서 딸기 스무디 는 어렵습니다 \n']
# p: ['카페라테 말씀 가능하십니다 \n']
# _
# q: ['따뜻한 라테 한 잔 주세요 \n']
# a: ['\t드시고 가시나요 \n']
# p: ['네 뜨거운 음료 로 드릴 까요 \n']
# _
# q: ['이 쿠키 도 함께 주세요 \n']
# a: ['\t네 쿠폰 찍어 드릴 까요 \n']
# p: ['네 쿠폰 음료 로 드릴 까요 \n']
# _
# q: ['프리 퀀시 적립 하고 있는데 시즌 메뉴 도 하나 만 적립 되나요 \n']
# a: ['\t네 그렇습니다 \n']
# p: ['네 그렇습니다 \n']
# _
# q: ['기프티콘 도 세트 메뉴 에 사용 가능한가요 \n']
# a: ['\t아니오 세트 메뉴 에는 기프티콘 사용 이 불가능합니다 \n']
# p: ['네 담아 드립니다 \n']
# _
# q: ['이 기프티콘 으로 대체 할 수 있는 시즌 메뉴 는 무엇 인가요 \n']
# a: ['\t기프티콘 으로 대체 할 수 있는 시즌 메뉴 는 없습니다 \n']
# p: ['네 같이 적립 해 드리겠습니다 \n']
# _
# q: ['그럼 두유 로 바꿔서 카페라테 두 잔 주세요 \n']
# a: ['\t카페라테 사이즈 는 어떻게 드릴 까요 \n']
# p: ['네 뜨거운 음료 로 드릴 까요 \n']
# _
# q: ['카페라테 라지 로 주세요 \n']
# a: ['\t드시고 가실 건가 요 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['아니요 가져갈 거 예요 \n']
# a: ['\t네 진동 벨 울리면 와주세요 \n']
# p: ['네 더 필요한 거 있으세요 \n']
# _
# q: ['커피 캐리어 도 주실 수 있나요 \n']
# a: ['\t네 캐리어 에 담아 드릴게요 \n']
# p: ['네 같이 적립 해 드리겠습니다 \n']
# _
# q: ['저 따뜻한 아메리카노 한 잔 하고 아이스 라테 한 잔 주세요 \n']
# a: ['\t더 필요한 건 없으시고요 \n']
# p: ['네 뜨거운 음료 로 드릴 까요 \n']
# _
# q: ['이 치즈케이크 도 한 조각 주세요 \n']
# a: ['\t여기 서 드실 건가 요 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['네 몇 분 정도 걸릴까 요 \n']
# a: ['\t주문 이 밀려서 7분 정도 걸릴 거 예요 \n']
# p: ['네 어떤 거 로 드릴 까요 \n']
# _
# q: ['네 2 층 이 넓은가요 \n']
# a: ['\t네 2 층 에 자리 많아요 \n']
# p: ['네 담아 드립니다 \n']
# _
# q: ['스무디 한 잔 주세요 \n']
# a: ['\t플레인 스무디 딸기스무디 키위 스무디 중 에 선택 해 주세요 \n']
# p: ['네 뜨거운 음료 로 드릴 까요 \n']
# _
# q: ['네 매장 에서 마실 거 예요 \n']
# a: ['\t머그잔 에 드릴게요 \n']
# p: ['네 가능합니다 \n']
# _
# q: ['아니요 아메리카노 뜨거운 걸 로 주세요 \n']
# a: ['\t드시고 가시나요 \n']
# p: ['네 뜨거운 음료 로 드릴 까요 \n']
# _
# q: ['여기 포인트 도 적립 되나요 \n']
# a: ['\t네 그럼요 \n']
# p: ['네 같이 적립 해 드리겠습니다 \n']
# _
# q: ['디카 페인 커피 도 판매 하나요 \n']
# a: ['\t네 저희 매장 에서는 디카 페인 과 하프 디카 페인 중 에 선택 하실 수 있습니다 \n']
# p: ['아뇨 매장 에서는 머그컵 만 사용 가능합니다 \n']
# _
# q: ['치즈케이크 도 한 조각 주세요 \n']
# a: ['\t네 총 9500원 결제 해드리겠습니다 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['영수증 챙겨주세요 \n']
# a: ['\t결제 완료 되셨고 영수증 여기 있습니다 \n']
# p: ['네 저희 가게 마스코트 메뉴 에요 \n']
# _
# q: ['딸기 주스 로 주세요 \n']
# a: ['\t네 더 필요한 건 없으세요 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['당근 케이크 같이 주세요 \n']
# a: ['\t네 알겠습니다 \n']
# p: ['네 뜨거운 음료 로 드릴 까요 \n']
# _
# q: ['카드 결제 할게요 \n']
# a: ['\t네 카드 받았습니다 \n']
# p: ['네 카드 가능합니다 \n']
# _
# q: ['플랫 화이트 가 뭔가 요 \n']
# a: ['\t플랫 화이트 는 카페라테 보다 우유 양 이 좀 적게 들어갔어요 \n']
# p: ['네 담아 드립니다 \n']
# _
# q: ['플랫 화이트 한 잔 주세요 \n']
# a: ['\t신 맛 과 고소한 맛 원두 중 에 어떤 걸 로 드릴 까요 \n']
# p: ['네 저희 적립 거 면 에요 \n']
# _
# q: ['고소한 맛 원두 로 부탁드릴게요 \n']
# a: ['\t플랫 화이트 사이즈 는 뭘 로 하시겠어요 \n']
# p: ['네 사이즈 는 뭘 로 알려 드리겠습니다 \n']
# _
# q: ['얼마 인가요 \n']
# a: ['\t플랫 화이트 4500원 입니다 \n']
# p: ['아니요 한 가능합니다 \n']
# _
# q: ['치즈케이크 있나요 \n']
# a: ['\t아니요 치즈케이크 는 지금 없어요 \n']
# p: ['네 가능합니다 \n']
# _
# q: ['아이스 아메리카노 두 잔 주세요 \n']
# a: ['\t드시고 가시나요 \n']
# p: ['네 뜨거운 음료 로 드릴 까요 \n']
# _
# q: ['차 종류 는 어떤 게 있나요 \n']
# a: ['\t차 종류 는 루이보스 랑 블랙 티 있어요 \n']
# p: ['아니요 한 사이즈 로만 판매 하고 있습니다 \n']
# _
# q: ['페퍼민트 는 없나요 \n']
# a: ['\t죄송합니다만 페퍼민트 는 방금 전 에 다 떨어졌어요 \n']
# p: ['네 담아 드립니다 \n']
# _
# q: ['카페인 이 적고 따뜻한 다른 음료 좀 추천 해주세요 \n']
# a: ['\t루이보스 차 나 밀크 티 종류 는 어떠세요 \n']
# p: ['네 담아 드립니다 \n']
# _
# q: ['밀크 티 는 티 를 직접 우려 서 나오는 건가 요 \n']
# a: ['\t네 밀크 티 는 블랙 티 를 우려 서 만들고 있어요 \n']
# p: ['네 티 는 블랙 티 음료 우려 음료 가능하세요 \n']
# _
# q: ['아이스 아메리카노 한 잔 주문 할게요 \n']
# a: ['\t네 알겠습니다 \n']
# p: ['네 알겠습니다 \n']
# _
# q: ['치즈 케이크 는 지금 없나요 \n']
# a: ['\t네 치즈케이크 는 지금 다 팔렸습니다 \n']
# p: ['네 담아 가능합니다 \n']
# _
# q: ['티라미슈 도 주세요 \n']
# a: ['\t네 진동 벨 울리면 찾으러 오세요 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['앞 접시 도 주실 수 있으신 가요 \n']
# a: ['\t네 앞 접시 도 같이 드리겠습니다 \n']
# p: ['네 같이 적립 해 드리겠습니다 \n']
# _
# q: ['따뜻한 아메리카노 한 잔 은 얼마 인가요 \n']
# a: ['\t4100원 입니다 \n']
# p: ['아뇨 매장 에서는 머그컵 만 사용 가능합니다 \n']
# _
# q: ['매장 영업 몇 시 까지 하나요 \n']
# a: ['\t매장 영업 시간 은 12시 까지라 지금 은 테이크아웃 만 가능하세요 \n']
# p: ['네 저희 가게 마스코트 입니다 \n']
# _
# q: ['마감 다 하실 때 까지 앉아있다 가면 안 되나요 \n']
# a: ['\t네 바닥 청소 도 해야 해서 죄송합니다 \n']
# p: ['아뇨 청소 은 재료 사용 해서 죄송합니다 \n']
# _
# q: ['아이스 아메리카노 두 잔 주세요 \n']
# a: ['\t네 총 8000원 입니다 \n']
# p: ['네 뜨거운 음료 로 드릴 까요 \n']
# _
# q: ['아이스 아메리카노 한 잔 에만 시럽 넣어주세요 \n']
# a: ['\t네 알겠습니다 \n']
# p: ['네 알겠습니다 \n']
# _
# q: ['와이파이 되나요 \n']
# a: ['\t와이파이 암호 는 가나다라 입니다 \n']
# p: ['네 가능합니다 \n']
# _
# q: ['화장실 이 어디 예요 \n']
# a: ['\t화장실 은 2 층 에 있습니다 \n']
# p: ['네 담아 드립니다 \n']
# _
# q: ['커피 말고 다른 음료 는 없나요 \n']
# a: ['\t티 와 주스 가 있습니다 \n']
# p: ['14 500원 입니다 \n']
# _
# q: ['아아 에 샷 추가 부탁드려요 \n']
# a: ['\t네 커피 가 많이 진할 수 있는데 괜찮으신 가요 \n']
# p: ['네 커피 는 지금 로 드리겠습니다 \n']
# _
# q: ['네 결제 는 삼 성 페이 로 할게요 \n']
# a: ['\t포인트 적립 카드 있으신 가요 \n']
# p: ['네 더 카드 카드 있으세요 \n']
# _
# q: ['네 휴대폰 번호 입력 할게요 \n']
# a: ['\t네 번호 입력 해주세요 \n']
# p: ['네 저희 가게 마스코트 거 요 \n']
# _
# q: ['카페 는 몇 시 까지 하나요 \n']
# a: ['\t11시 까지 합니다 \n']
# p: ['네 배달 비 3000원 입니다 \n']
# _
# q: ['아아 에 얼음 많이 넣어주세요 \n']
# a: ['\t네 다 되면 진동 벨 로 알려 드릴게요 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['아메리카노 기프티콘 사용 할 수 있나요 \n']
# a: ['\t네 가능하세요 \n']
# p: ['네 같이 적립 해 드리겠습니다 \n']
# _
# q: ['아메리카노 기프티콘 사용 해주세요 \n']
# a: ['\t바코드 를 앞 에 기계 에 대어주세요 \n']
# p: ['네 담아 드립니다 \n']
# _
# q: ['기계 바코드 인식 이 잘 안되는데요 \n']
# a: ['\t제 가 해드리겠습니다 \n']
# p: ['네 담아 에서는 머그컵 에요 \n']
# _
# q: ['네 기프티콘 여기 있어요 \n']
# a: ['\t아메리카노 기프티콘 사용 되었습니다 \n']
# p: ['네 담아 드립니다 \n']
# _
# q: ['오늘 의 커피 는 뭔가 요 \n']
# a: ['\t아메리카노 와 카페모카 입니다 \n']
# p: ['네 붕어빵 이 인기 에요 \n']
# _
# q: ['카페모카 주세요 \n']
# a: ['\t휘핑크림 올려 드릴 까요 \n']
# p: ['네 드시고 가시나요 \n']
# _
# q: ['아니요 그냥 주세요 \n']
# a: ['\t카페모카 5천 원 입니다 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['카드 로 할게요 \n']
# a: ['\t네 잠시 만 기다려주세요 \n']
# p: ['네 알겠습니다 \n']
# _
# q: ['빨대 는 어디 있나요 \n']
# a: ['\t네 이 쪽 에 있습니다 \n']
# p: ['쪽 이 2 해 드리겠습니다 \n']
# _
# q: ['샌드위치 랑 카페라테 주세요 \n']
# a: ['\t커피 는 따뜻하게 드릴 까요 \n']
# p: ['네 저희 카드 은 없으신 가요 \n']
# _
# q: ['네 샌드위치 도 데워주실 수 있죠 \n']
# a: ['\t그럼요 \n']
# p: ['네 같이 적립 해 드리겠습니다 \n']
# _
# q: ['물티슈 도 챙겨 주세요 \n']
# a: ['\t네 드시고 가시나요 \n']
# p: ['네 드시고 가시나요 \n']
# _
# q: ['단체 주문 가능한가요 \n']
# a: ['\t물론 이 죠 \n']
# p: ['네 500원 가능합니다 \n']
# _
# q: ['아이스 아메리카노 30 개 주세요 \n']
# a: ['\t네 단체 주문 은 재료 추가 불가능합니다 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['라테 20 개 주문 할게요 \n']
# a: ['\t총 50 개 주문 받았습니다 \n']
# p: ['네 알겠습니다 \n']
# _
# q: ['그럼 한 시간 후 에 음료 찾으러 오면 될까 요 \n']
# a: ['\t네 계산 도 와 드릴게요 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['포인트 랑 쿠폰 적립 해주세요 \n']
# a: ['\t다 되셨습니다 \n']
# p: ['네 담아 드립니다 \n']
# _
# q: ['커피 와 조각 케이크 세트 로 판매 하시나요 \n']
# a: ['\t네 있습니다 \n']
# p: ['14 있습니다 \n']
# _
# q: ['세트 종류 가 어떤 게 있죠 \n']
# a: ['\t이 쪽 에서 고르시면 됩니다 \n']
# p: ['쪽 한 사이즈 로만 판매 하고 있습니다 \n']
# _
# q: ['아메리카노 티라미슈 세트 가격 은 어떻게 되죠 \n']
# a: ['\t아메리카노 티라미슈 세트 가격 은 만 원 입니다 \n']
# p: ['네 저희 가게 마스코트 거 요 \n']
# _
# q: ['아메리카노 를 카페모카 로 변경 가능한가요 \n']
# a: ['\t가능합니다만 가격 이 천 원 더 올라가게 됩니다 \n']
# p: ['아뇨 매장 에서는 머그컵 만 사용 가능합니다 \n']
# _
# q: ['그러면 아메리카노 티라미슈 세트 에 카페모카 로 변경 해서 주문 하겠습니다 \n']
# a: ['\t네 잠시 만 기다려주세요 \n']
# p: ['네 저희 가게 마스코트 메뉴 에요 \n']
# _
# q: ['아이스 아메리카노 되나요 \n']
# a: ['\t네 가능합니다 \n']
# p: ['아니요 가능합니다 \n']
# _
# q: ['얼음 량 조절 적게 되나요 \n']
# a: ['\t네 가능합니다 \n']
# p: ['아니요 가능합니다 \n']
# _
# q: ['머핀 은 얼마 에요 \n']
# a: ['\t베이글 과 동일하게 2000원 입니다 \n']
# p: ['네 가능합니다 \n']
# _
# q: ['베이글 과 머핀 전부 주세요 \n']
# a: ['\t준비 해드리겠습니다 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['그럼 아메리카노 랑 바닐라 라테 주세요 \n']
# a: ['\t둘 다 아이스 인가요 \n']
# p: ['네 뜨거운 음료 로 드릴 까요 \n']
# _
# q: ['네 여기 있습니다 \n']
# a: ['\t손님 지금 15000 포인트 있으신 데 사용 해 드릴 까요 \n']
# p: ['네 어떤 거 로 드릴 까요 \n']
# _
# q: ['기프트카드 포인트 결제 되나요 \n']
# a: ['\t네 됩니다 \n']
# p: ['쪽 한 사이즈 로만 판매 하고 있습니다 \n']
# _
# q: ['혹시 기존 카드 로 통합 시킬 수도 있나요 \n']
# a: ['\t네 합쳐 드릴 까요 \n']
# p: ['네 뜨거운 음료 로 드릴 까요 \n']
# _
# q: ['네 합쳐주시고 아이스 아메리카노 한잔 주세요 \n']
# a: ['\t드시고 가실 건가 요 \n']
# p: ['네 드시고 가세 요 \n']
# _
# q: ['먹고 갈 건데 혹시 일회용 컵 에 담아주실 수 있을까요 \n']
# a: ['\t매장 에서 드실 거 면 머그컵 에 드리도록 되어있습니다 \n']
# p: ['네 어떤 거 로 드릴 까요 \n']
# _
# q: ['마시다 나갈 거니 일회용 컵 에 담아주실 수 는 없을까요 \n']
# a: ['\t네 일회용 컵 에 담아 드리겠습니다 \n']
# p: ['네 담아 드립니다 \n']
# _
# q: ['아메리카노 하나 주세요 \n']
# a: ['\t따뜻한 걸 로 드릴 까요 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['아니요 아이스 로 주세요 \n']
# a: ['\t레귤러 사이즈 로 괜찮으세요 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['초코 라테 한잔 주세요 \n']
# a: ['\t휘핑크림 올려 드릴 까요 \n']
# p: ['네 드시고 가시나요 \n']
# _
# q: ['아메리카노 한 잔 주세요 \n']
# a: ['\t따뜻한 것 과 아이스 중 에 무엇 을 드릴 까요 \n']
# p: ['네 뜨거운 음료 로 드릴 까요 \n']
# _
# q: ['아이스 로 주세요 \n']
# a: ['\t네 시럽 넣어 드릴 까요 \n']
# p: ['네 드시고 가시나요 \n']
# _
# q: ['아니요 시럽 은 빼주세요 \n']
# a: ['\t네 드시고 가실 건가 요 \n']
# p: ['네 어떤 걸 로 드릴 까요 \n']
# _
# q: ['아니요 테이크 아웃 이 요 \n']
# a: ['\t네 1500원 결제 도 와 드리겠습니다 \n']
# p: ['네 알겠습니다 \n']
# _
# q: ['여기 카드 로 결제 해주세요 \n']
# a: ['\t네 알겠습니다 \n']
# p: ['네 담아 드립니다 \n']
# _
# q: ['아메리카노 두 잔 이랑 치즈케이크 한 개 주세요 \n']
# a: ['\t아메리카노 두 잔 치즈케이크 한 개 주문 도 와 드리면 될까 요 \n']
# p: ['네 뜨거운 음료 로 드릴 까요 \n']
# _
# q: ['네 따뜻하게 해주세요 \n']
# a: ['\t다해 서 10900원 입니다 \n']
# p: ['네 주문 가능합니다 \n']
# _
# q: ['현금영수증 도 해주시 죠 \n']
# a: ['\t네 영수증 드릴게요 \n']
# p: ['네 배달 비 3000원 입니다 \n']
# _
# q: ['아메리카노 따뜻한 거 라지 사이즈 로 주세요 \n']
# a: ['\t다른 건 필요 없으신 가요 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['티라미수 케이크 도 주세요 \n']
# a: ['\t적립 카드 있으신 가요 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['번호 로 할게요 \n']
# a: ['\t주차 는 하셨나요 \n']
# p: ['네 어떤 거 로 드릴 까요 \n']
# _
# q: ['주차 안 했어요 \n']
# a: ['\t진동 벨 로 알려 드리겠습니다 \n']
# p: ['네 담아 드립니다 \n']
# _
# q: ['자몽 차는 있나요 \n']
# a: ['\t네 자몽 차는 있습니다 \n']
# p: ['아니요 한 사이즈 로만 판매 하고 있습니다 \n']
# _
# q: ['그럼 자몽 차 한잔 주세요 \n']
# a: ['\t따뜻하게 드릴 까요 \n']
# p: ['네 드시고 가시나요 \n']
# _
# q: ['저번 에 와서 먹은 미숫가루 라테 가 오늘 은 없네요 \n']
# a: ['\t네 그건 시즌 한정 메뉴 라 겨울 에는 판매 하지 않습니다 \n']
# p: ['네 그건 적립 메뉴 메뉴 에요 \n']
# _
# q: ['사이드 메뉴 중 엔 맛있는 게 뭔가 요 \n']
# a: ['\t인절미 쏙쏙 붕어빵 이 인기 에요 \n']
# p: ['네 붕어빵 이 인기 에요 \n']
# _
# q: ['그럼 감귤 라테 2 잔 이랑 인절미 쏙쏙 붕어빵 2 개 주세요 \n']
# a: ['\t드시고 가시나요 \n']
# p: ['네 뜨거운 음료 로 드릴 까요 \n']
# _
# q: ['아메리카노 한잔 주세요 \n']
# a: ['\t따뜻한 걸 로 드릴 까요 \n']
# p: ['네 드시고 가시나요 \n']
# _
# q: ['아이스 아메리카노 로 주세요 \n']
# a: ['\t아이스 아메리카노 한잔 주문 도 와 드리겠습니다 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['초코 머핀 도 하나 추가 해주세요 \n']
# a: ['\t초코 머핀 어떤 걸 로 드릴 까요 \n']
# p: ['네 어떤 거 로 드리겠습니다 \n']
# _
# q: ['화이트 로 부탁 해요 \n']
# a: ['\t아이스 아메리카노 한잔 화이트 초코 머핀 1 개 주문 도 와 드리겠습니다 \n']
# p: ['네 알겠습니다 \n']
# _
# q: ['얼마 예요 \n']
# a: ['\t총 7000원 입니다 \n']
# p: ['아니요 한 가능합니다 \n']
# _
# q: ['아메리카노 한 잔 이랑 바닐라 라테 한 잔 주세요 \n']
# a: ['\t둘 다 따뜻한 거 맞으세요 \n']
# p: ['네 뜨거운 음료 로 드릴 까요 \n']
# _
# q: ['아니요 아메리카노 는 아이스 로 주세요 \n']
# a: ['\t네 음료 사이즈 는 어떤 걸 로 하시겠어요 \n']
# p: ['네 음료 음료 로 드릴 까요 \n']
# _
# q: ['여기 쿠폰 이 요 \n']
# a: ['\t네 고객 님 결제 완료 되었습니다 \n']
# p: ['네 어떤 케이크 로 드리겠습니다 \n']
# _
# q: ['네 따뜻한 걸 로 주세요 \n']
# a: ['\t드시고 가시나요 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['네 여기 서 먹고 갈 거 예요 \n']
# a: ['\t그럼 머그잔 에 드릴게요 \n']
# p: ['네 더 필요한 거 있으세요 \n']
# _
# q: ['혹시 휘핑크림 추가 되나요 \n']
# a: ['\t네 500원 추가 하시면 추가 돼요 \n']
# p: ['아뇨 가능합니다 \n']
# _
# q: ['갈릭 치즈 브레드 에 생크림 을 올려주실 수 는 없나요 \n']
# a: ['\t500원 의 추가 비용 이 발생 되는데 괜찮으세요 \n']
# p: ['네 같이 적립 해 드리겠습니다 \n']
# _
# q: ['아이스 바닐라 라테 도 한 잔 주세요 \n']
# a: ['\t네 진동 벨 이 울리면 픽업 대로 와주세요 \n']
# p: ['네 뜨거운 음료 로 드릴 까요 \n']
# _
# q: ['라테 한 잔 에 얼마 인가요 \n']
# a: ['\t5000원 입니다 \n']
# p: ['아뇨 매장 은 머그컵 만 사용 가능합니다 \n']
# _
# q: ['마카롱 은 남아있나요 \n']
# a: ['\t오늘 은 다 팔렸어요 \n']
# p: ['네 가능합니다 \n']
# _
# q: ['그러면 스콘 하나 랑 라테 한 잔 주세요 \n']
# a: ['\t네 적립 쿠폰 주시 면 적립 해드릴게요 \n']
# p: ['네 뜨거운 음료 로 드릴 까요 \n']
# _
# q: ['혹시 적립 쿠폰 으로 커피 계산 할 수 있나요 \n']
# a: ['\t네 됩니다 \n']
# p: ['네 500원 할인 하시면 있습니다 \n']
# _
# q: ['그러면 커피 는 쿠폰 으로 스콘 은 카드 로 계산 해주세요 \n']
# a: ['\t알겠습니다 \n']
# p: ['네 담아 드립니다 \n']
# _
# q: ['아이스 아메리카노 에 얼음 조금 덜 넣어주실 수 있나요 \n']
# a: ['\t네 또 더 필요한 거 있으세요 \n']
# p: ['네 더 필요한 거 있으세요 \n']
# _
# q: ['네 블루베리 스무디 1 개 더 추가 로 주세요 \n']
# a: ['\t드시고 가시나요 \n']
# p: ['네 뜨거운 음료 로 드릴 까요 \n']
# _
# q: ['아니요 테이크아웃 이 요 \n']
# a: ['\t네 포인트 적립 하시나요 \n']
# p: ['네 어떤 거 로 드릴 까요 \n']
# _
# q: ['아니요 기프티콘 으로 결제 할게요 \n']
# a: ['\t저 한테 보여주시고 제 가 확인 버튼 누르면 돼요 \n']
# p: ['네 같이 적립 해 드리겠습니다 \n']
# _
# q: ['핫초코 파나요 \n']
# a: ['\t네 4500원 입니다 \n']
# p: ['4500원 입니다 \n']
# _
# q: ['핫초코 한잔 아메리카노 한잔 하면 얼마 인가요 \n']
# a: ['\t9500원 입니다 \n']
# p: ['14 4500원 입니다 \n']
# _
# q: ['사이즈 업 되나요 \n']
# a: ['\t아메리카노 만 사이즈 업 가능하십니다 \n']
# p: ['아니요 한 사이즈 로만 판매 하고 있습니다 \n']
# _
# q: ['레몬 티 도 파나요 \n']
# a: ['\t네 4500원 입니다 \n']
# p: ['4500원 입니다 \n']
# _
# q: ['제일 맛있는 케이크 가 뭐 예요 \n']
# a: ['\t치즈 케이크 가 잘 팔려요 \n']
# p: ['네 담아 드립니다 \n']
# _
# q: ['한 조각 에 얼마 죠 \n']
# a: ['\t4000원 입니다 \n']
# p: ['14 500원 입니다 \n']
# _
# q: ['그거 랑 아메리카노 주세요 \n']
# a: ['\t사이즈 선택 해주세요 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['라지 사이즈 로 주세요 \n']
# a: ['\t총 8800원 입니다 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['카드 로 결제 할게요 \n']
# a: ['\t영수증 드릴게요 \n']
# p: ['네 가능합니다 \n']
# _
# q: ['저 아메리카노 에 샷 추가 해서 주세요 \n']
# a: ['\t저희 투 샷 으로 들어가는데 샷 추가 해드릴까 요 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['네 4 샷 으로 넣어주세요 \n']
# a: ['\t네 4000원 입니다 \n']
# p: ['네 담아 드립니다 \n']
# _
# q: ['저 카카오 페이 로 결제 할게요 \n']
# a: ['\t결제 완료 되었습니다 \n']
# p: ['네 더 필요한 거 있으세요 \n']
# _
# q: ['아 저 이 티라미수 도 하나 주세요 \n']
# a: ['\t네 티라미수 는 4500원 입니다 \n']
# p: ['네 더 더 카드 있으세요 \n']
# _
# q: ['네 두 개 함께 가져다주세요 \n']
# a: ['\t네 감사합니다 \n']
# p: ['네 저희 가게 3000원 입니다 \n']
# _
# q: ['제 가 커피 를 못 마시는데 음료 좀 추천 해주세요 \n']
# a: ['\t그럼 생 과 일 주스 가 어떠신 가요 \n']
# p: ['네 알겠습니다 \n']
# _
# q: ['카드 로 결제 할게요 \n']
# a: ['\t네 감사합니다 \n']
# p: ['네 가능합니다 \n']
# _
# q: ['디카 페인 음료 주문 가능할까 요 \n']
# a: ['\t네 디카 페인 라테 아메리카노 주문 가능합니다 \n']
# p: ['아뇨 매장 가능합니다 \n']
# _
# q: ['그럼 디카 페인 라테 한잔 해주세요 \n']
# a: ['\t네 다른 필요하신 건 없으신 가요 \n']
# p: ['네 뜨거운 음료 로 드릴 까요 \n']
# _
# q: ['멤버십 으로 사이 즈 업 해주세요 \n']
# a: ['\t네 사이즈 업 도 와 드리겠습니다 \n']
# p: ['네 사이즈 는 사이즈 업 드리겠습니다 \n']
# _
# q: ['네 엘지 파이 로 계산 할게요 \n']
# a: ['\t네 엘지 파이 로 결제 도 와 드리겠습니다 \n']
# p: ['네 어떤 거 로 드릴 까요 \n']
# _
# q: ['플렛 화이트 아이스 도 있나요 \n']
# a: ['\t네 있습니다 \n']
# p: ['네 가능합니다 \n']
# _
# q: ['머핀 이나 케이크 도 있나요 \n']
# a: ['\t네 초코 머핀 이랑 치즈케이크 있습니다 \n']
# p: ['네 가능합니다 \n']
# _
# q: ['그럼 초코 머핀 하나 주세요 \n']
# a: ['\t초코 머핀 데워 드릴 까요 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['기프트 콘 사용 가능하나요 \n']
# a: ['\t네 가능합니다 \n']
# p: ['아니요 가능합니다 \n']
# _
# q: ['바닐라 라테 진하게 가능할까 요 \n']
# a: ['\t네 그럼 시럽 많이 넣어 드릴게요 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['아이스 인데 얼음 없이 줄 수 있으세요 \n']
# a: ['\t얼음 아예 빼는 건 안되고 최대한 조금 넣어 드릴게요 \n']
# p: ['네 어떤 거 로 드릴 까요 \n']
# _
# q: ['쿠폰 10 개 다 모았는데 사용 가능할까 요 \n']
# a: ['\t쿠폰 은 아메리카노 만 사용 가능하세요 \n']
# p: ['14 500원 입니다 \n']
# _
# q: ['조금 만 앉아있다가 나갈 건데 일회용 컵 에는 안될까 요 \n']
# a: ['\t앉아계실 거 면 컵 만 가능하세요 \n']
# p: ['네 저희 필요한 거 없으신 가요 \n']
# _
# q: ['아이스 로 주세요 \n']
# a: ['\t드시고 가시나요 \n']
# p: ['네 드시고 가시나요 \n']
# _
# q: ['아니요 그냥 결제 해주세요 \n']
# a: ['\t결제 도 와 드리겠습니다 \n']
# p: ['네 담아 드립니다 \n']
# _
# q: ['현금 으로 할게요 \n']
# a: ['\t현금영수증 해드릴까 요 \n']
# p: ['네 어떤 거 로 드릴 까요 \n']
# _
# q: ['아메리카노 한 잔 주세요 \n']
# a: ['\t아이스 로 드릴 까요 \n']
# p: ['네 뜨거운 음료 로 드릴 까요 \n']
# _
# q: ['이 쿠키 는 뭐 예요 \n']
# a: ['\t초코 칩 쿠키 입니다 \n']
# p: ['네 담아 드립니다 \n']
# _
# q: ['이 것 도 하나 주시는데 얼마 에요 \n']
# a: ['\t2000원 입니다 \n']
# p: ['14 500원 입니다 \n']
# _
# q: ['네 여기 현금영수증 도 해주세요 \n']
# a: ['\t네 번호 적어주세요 \n']
# p: ['네 어떤 거 로 드릴 까요 \n']
# _
# q: ['아이스 아메리카노 하나 따뜻한 자몽 치 하나 주세요 \n']
# a: ['\t아메리카노 원두 는 어떤 걸 로 할까 요 \n']
# p: ['네 더 카드 카드 있으세요 \n']
# _
# q: ['많이 쓴가요 \n']
# a: ['\t쓴맛 은 많이 없고 산미 가 있고 다른 원두 들 보다 과일 향 이 나죠 \n']
# p: ['네 배달 비 3000원 입니다 \n']
# _
# q: ['그러면 예 가체 프로 주세요 \n']
# a: ['\t부드러워서 아메리카노 안 좋아하시는 분 들 도 많이 선택 하세요 \n']
# p: ['네 더 더 카드 있으세요 \n']
# _
# q: ['테이크 아웃 으로 해주세요 \n']
# a: ['\t네 진동 벨 울리면 픽업 테이블 로 와주세요 \n']
# p: ['네 어떤 거 로 드릴 까요 \n']
# _
# q: ['아이스 말차 라테 에 에스프레소 샷 하나 추가 해서 주세요 \n']
# a: ['\t네 따로 추가 하실 건 없으신 가요 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['지금 말차 케이크 는 품절 인 거 죠 \n']
# a: ['\t네 죄송하지만 말차 케이크 는 품절 되었습니다 \n']
# p: ['네 가능합니다 \n']
# _
# q: ['그럼 말차 라테 에 잘 어울리는 케이크 하나 추천 해주시겠어요 \n']
# a: ['\t치즈 케이크 가 잘 어울려서 같이 주문 하시는 고객 님 들이 많으세요 \n']
# p: ['네 주문 적립 해 면 됩니다 \n']
# _
# q: ['네 매장 에서 먹고 갈게요 \n']
# a: ['\t네 그럼 바로 준비 해드리겠습니다 \n']
# p: ['네 어떤 거 로 드릴 까요 \n']
# _
# q: ['그린 티 프라푸치노 하나 주세요 \n']
# a: ['\t네 사이즈 는 어떻게 드릴 까요 \n']
# p: ['네 뜨거운 음료 로 드릴 까요 \n']
# _
# q: ['스타벅스 카드 로 계산 할게요 \n']
# a: ['\t사용 하시고 잔액 3천 원 인데 충전 하시겠어요 \n']
# p: ['네 배달 비 3000원 입니다 \n']
# _
# q: ['네 2만 원 충전 해주세요 \n']
# a: ['\t네 알겠습니다 \n']
# p: ['네 알겠습니다 \n']
# _
# q: ['에스프레소 한 잔 하고 카페모카 두 잔 주세요 \n']
# a: ['\t카페모카 사이즈 는 어떤 걸 드릴 까요 \n']
# p: ['네 뜨거운 음료 로 드릴 까요 \n']
# _
# q: ['그 랑 데 사이즈 로 주 십 시오 \n']
# a: ['\t드시고 가실 건가 요 \n']
# p: ['네 배달 비 3000원 입니다 \n']
# _
# q: ['할인 카드 있습니다 \n']
# a: ['\t할인 되어 1만 1천 원 입니다 \n']
# p: ['네 어떤 거 로 드릴 까요 \n']
# _
# q: ['핫초코 에 우유 를 더 많이 타서 연하게 만들어주실 수 있나요 \n']
# a: ['\t네 그렇게 해드리겠습니다 \n']
# p: ['아뇨 매장 에서는 머그컵 사용 사용 이 불가능합니다 \n']
# _
# q: ['얼마 인가요 \n']
# a: ['\t5천 원 입니다 \n']
# p: ['아니요 한 가능합니다 \n']
# _
# q: ['아이스 로 변경 할 경우 추가 요금 이 있나요 \n']
# a: ['\t아이스 음료 는 500원 이 더 비쌉니다 \n']
# p: ['네 같이 가능합니다 \n']
# _
# q: ['그냥 따뜻한 걸 로 주시 고 따뜻한 아메리카노 도 한잔 더 주실 수 있나요 \n']
# a: ['\t들고 가실 건가 요 \n']
# p: ['아뇨 매장 에서는 머그컵 만 사용 가능합니다 \n']
# _
# q: ['네 안전히 들고 갈 수 있게 부탁드립니다 \n']
# a: ['\t손잡이 있는 캐리어 에 담아 드리겠습니다 \n']
# p: ['네 캐리어 에 담아 드리겠습니다 \n']
# _
# q: ['밀크 티 한 잔 얼마 에요 \n']
# a: ['\t4500원 입니다 \n']
# p: ['14 더 입니다 \n']
# _
# q: ['사이즈 업 되나요 \n']
# a: ['\t네 \n']
# p: ['아니요 한 사이즈 로만 판매 하고 있습니다 \n']
# _
# q: ['케이크 는 뭐 가 제일 맛있어요 \n']
# a: ['\t요즘 은 초코 케이크 가 제일 잘나가요 \n']
# p: ['네 가능합니다 \n']
# _
# q: ['초코 케이크 한 조각 주세요 \n']
# a: ['\t네 더 필요하신 건 없으세요 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['현금 영수증 해주세요 \n']
# a: ['\t네 번호 찍어주세요 \n']
# p: ['네 저희 가게 마스코트 메뉴 에요 \n']
# _
# q: ['카페라테 가격 은 얼마 인가요 \n']
# a: ['\t5000원 입니다 \n']
# p: ['아뇨 매장 에서는 머그컵 만 사용 가능합니다 \n']
# _
# q: ['멤버십 있는데 포인트 쓸 수 있나요 \n']
# a: ['\t네 포인트 사용 가능하세요 \n']
# p: ['네 같이 적립 해 드리겠습니다 \n']
# _
# q: ['포인트 사용 하고 적립 동시 에 가능한가요 \n']
# a: ['\t포인트 사용 하시면 적립 은 안됩니다 \n']
# p: ['네 같이 적립 해 드리겠습니다 \n']
# _
# q: ['포인트 사용 없이 적립 만 할게요 \n']
# a: ['\t네 멤버십 카드 주시 면 도 와 드리겠습니다 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['멤버십 카드 드리고 현금 으로 계산 할게요 \n']
# a: ['\t네 현금영수증 해드릴까 요 \n']
# p: ['네 담아 드립니다 \n']
# _
# q: ['아이스 아메리카노 주세요 \n']
# a: ['\t샌드위치 는 안 필요하신가요 \n']
# p: ['네 드시고 가시나요 \n']
# _
# q: ['현금영수증 도 할게요 \n']
# a: ['\t네 번호 입력 해주세요 \n']
# p: ['네 어떤 거 로 드릴 까요 \n']
# _
# q: ['포장 이 요 \n']
# a: ['\t5500원 입니다 \n']
# p: ['네 주문 가능합니다 \n']
# _
# q: ['적립 도 해주세요 \n']
# a: ['\t알겠습니다 \n']
# p: ['네 어떤 거 로 드릴 까요 \n']
# _
# q: ['아이스 아메리카노 하나 랑 녹차 라테 주세요 \n']
# a: ['\t녹차 라테 도 아이스 로 드릴 까요 \n']
# p: ['네 뜨거운 음료 로 드릴 까요 \n']
# _
# q: ['녹차 라테 는 따뜻하게 주세요 \n']
# a: ['\t사이즈 는 어떻게 드릴 까요 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['테이크아웃 잔 으로 주세요 \n']
# a: ['\t올해 부터는 점포 안 에서 1회 용을 사용 하실 수 없습니다 \n']
# p: ['네 뜨거운 음료 로 드릴 까요 \n']
# _
# q: ['무료 인가요 \n']
# a: ['\t500 원 추가 입니다 \n']
# p: ['네 가능합니다 \n']
# _
# q: ['추가 해주세요 \n']
# a: ['\t자리 에 앉아 계시 면 가져다 드리겠습니다 \n']
# p: ['네 어떤 거 로 드릴 까요 \n']
# _
# q: ['아메리카노 교환 권 이 있는데 다른 걸 로 바꿀 수 있을까요 \n']
# a: ['\t가능한데 어떤 걸 로 바꿔 드릴 까요 \n']
# p: ['네 어떤 거 로 드릴 까요 \n']
# _
# q: ['통신사 쿠폰 사용 해서 라지 사이즈 로 해주세요 \n']
# a: ['\t이 곳 에 바코드 찍어주세요 \n']
# p: ['네 담아 드립니다 \n']
# _
# q: ['추가 요금 은 얼마 인가요 \n']
# a: ['\t500원 결제 해주시면 됩니다 \n']
# p: ['14 500원 입니다 \n']
# _
# q: ['이 카드 로 해주세요 \n']
# a: ['\t음료 나오면 진동 벨 로 알려 드리겠습니다 \n']
# p: ['나오면 진동 벨 로 알려 드리겠습니다 \n']
# _
# q: ['아이스 아메리카노 1 잔 이랑 아이스 카페라테 1 잔 얼마 인가요 \n']
# a: ['\t아이스 아메리카노 1 잔 은 4000원 아이스 카페라테 1 잔 은 5000원 입니다 \n']
# p: ['아뇨 매장 에서는 머그컵 만 사용 가능합니다 \n']
# _
# q: ['멤버십 할인 되나요 \n']
# a: ['\t네 멤버십 할인 하시면 10 퍼센트 할인 됩니다 \n']
# p: ['네 가능합니다 \n']
# _
# q: ['기프티콘 있는데 쓸 수 있나요 \n']
# a: ['\t네 유효 기간 내 라면 사용 가능하세요 \n']
# p: ['네 같이 적립 해 드리겠습니다 \n']
# _
# q: ['여기 에서 지하철 타려면 어느 역 으로 가야 하나요 \n']
# a: ['\t분당선 압구정 로데오 역 을 이용 하시면 됩니다 \n']
# p: ['네 담아 드립니다 \n']
# _
# q: ['여기 주차 되나요 \n']
# a: ['\t건물 뒤 에 주차장 있습니다 \n']
# p: ['아니요 한 사이즈 로만 판매 하고 있습니다 \n']
# _
# q: ['쿠앤크 치노 하나요 \n']
# a: ['\t아이스 로 드릴 까요 \n']
# p: ['네 알겠습니다 \n']
# _
# q: ['네 아이스 요 \n']
# a: ['\t드시고 가세 요 \n']
# p: ['네 저희 가게 마스코트 메뉴 에요 \n']
# _
# q: ['네 먹고 가요 \n']
# a: ['\t계산 은 어떻게 하실 건가 요 \n']
# p: ['네 어떤 거 로 드릴 까요 \n']
# _
# q: ['여기 카드 로 결제 해주세요 \n']
# a: ['\t네 결제 해드렸습니다 \n']
# p: ['네 담아 드립니다 \n']
# _
# q: ['카페인 안 들은 음료 는 뭐 가 있을까요 \n']
# a: ['\t피지 와 나 티 종류 가 있습니다 \n']
# p: ['네 담아 드립니다 \n']
# _
# q: ['피지 와는 어떤 게 있어요 \n']
# a: ['\t라임 하고 자몽 이 있습니다 \n']
# p: ['14 하고 종류 는 블랙 드리겠습니다 \n']
# _
# q: ['둘 중 에 어떤 게 더 잘 나가요 \n']
# a: ['\t자몽 이 조금 더 잘 나가요 \n']
# p: ['네 더 카드 카드 있으세요 \n']
# _
# q: ['자몽 피지 와 주세요 \n']
# a: ['\t네 더 필요하신 건 없으세요 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['티 종류 도 아이스 가능한가요 \n']
# a: ['\t네 고객 님 티 종류 다 아이스 가능합니다 \n']
# p: ['네 가능합니다 \n']
# _
# q: ['그럼 캐머 마일 아이스 로 하나 주세요 \n']
# a: ['\t네 고객 님 사이즈 는 톨 사이즈 괜찮으신 가요 \n']
# p: ['네 더 필요한 거 있으세요 \n']
# _
# q: ['네 괜찮아요 \n']
# a: ['\t네 고객 님 포인트 적립 하시겠어요 \n']
# p: ['네 가능합니다 \n']
# _
# q: ['화이트 모카 한 잔 주세요 \n']
# a: ['\t드시고 가세 요 \n']
# p: ['네 저희 적립 맛 있으세요 \n']
# _
# q: ['아뇨 테이크아웃 이 요 \n']
# a: ['\t휘핑 올려 드릴 까요 \n']
# p: ['네 어떤 거 로 드릴 까요 \n']
# _
# q: ['따뜻한 걸 로 주세요 \n']
# a: ['\t사이즈 는 어떻게 드릴 까요 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['아이스 아메리카노 하나 랑 카페모카 하나 주세요 \n']
# a: ['\t카페모카 도 아이스 맞으세요 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['카페모카 는 따뜻한 거 로 주세요 \n']
# a: ['\t카페모카 위 에 휘핑 올려 드릴 까요 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['아직 런치 세트 할인 되나요 \n']
# a: ['\t네 2시 까지 가능하십니다 \n']
# p: ['아뇨 매장 에서는 디카 페인 사용 가능합니다 \n']
# _
# q: ['치킨 파야냐 하나 랑 아이스 아메리카노 하나 해서 주세요 \n']
# a: ['\t네 더 추가 하실 것 은 없으신 가요 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['삼성 페이 되나요 \n']
# a: ['\t네 가능합니다 \n']
# p: ['아니요 한 사이즈 로만 판매 하고 됩니다 \n']
# _
# q: ['리저브 는 처음 인데 요 \n']
# a: ['\t네 원하시는 원두 와 내리는 방법 을 선택 하실 수 있습니다 \n']
# p: ['네 저희 가게 카드 있으세요 \n']
# _
# q: ['네 평소 에 아메리카노 를 주로 마시는데요 \n']
# a: ['\t네 과테말라 와 케냐 를 섞은 마이크로 블렌드 를 추천 하겠습니다 \n']
# p: ['네 저희 가게 마스코트 에요 \n']
# _
# q: ['어떤 맛 인가요 \n']
# a: ['\t다크 초콜릿 이 어우러진 달콤한 맛 입니다 \n']
# p: ['네 담아 드립니다 \n']
# _
# q: ['전 단것 은 별로 인데 요 \n']
# a: ['\t아주 단맛 이 아닌데요 \n']
# p: ['네 같이 드립니다 \n']
# _
# q: ['그럼 커피 와 어우러지는 케이크 도 추천 해 주세요 \n']
# a: ['\t상큼 한 블루베리 머핀 이나 레드 벨벳 크림 치즈케이크 가 어울립니다 \n']
# p: ['네 사이즈 는 톨 사이즈 음료 로 드릴 까요 \n']
# _
# q: ['카페라테 주세요 \n']
# a: ['\t네 드시고 가시나요 \n']
# p: ['네 드시고 가시나요 \n']
# _
# q: ['아니요 테이크아웃 이 요 \n']
# a: ['\t네 알겠습니다 \n']
# p: ['네 어떤 거 로 드릴 까요 \n']
# _
# q: ['네 카드 여기 요 \n']
# a: ['\t적립 쿠폰 있으세요 \n']
# p: ['네 가능합니다 \n']
# _
# q: ['아니오 하나 만들어 주세요 \n']
# a: ['\t네 카드 랑 쿠폰 여기 있습니다 \n']
# p: ['네 카드 음료 는 랑 티 있습니다 \n']
# _
# q: ['아메리카노 1 잔 주세요 \n']
# a: ['\t매장 에서 드시고 가시나요 \n']
# p: ['네 뜨거운 음료 로 드릴 까요 \n']
# _
# q: ['바닐라 라테 를 두유 로 바꿔서 만들어주세요 \n']
# a: ['\t네 알겠습니다 \n']
# p: ['네 어떤 거 로 드릴 까요 \n']
# _
# q: ['2 잔 주문 하면 얼마 죠 \n']
# a: ['\t7000원 입니다 \n']
# p: ['14 500원 입니다 \n']
# _
# q: ['모카 라테 1 잔 주세요 \n']
# a: ['\t휘핑크림 올려 드릴 까요 \n']
# p: ['네 저희 적립 거 면 머그컵 에 주문 가능합니다 \n']
# _
# q: ['치즈케이크 하나 추가 해주세요 \n']
# a: ['\t네 알겠습니다 \n']
# p: ['네 배달 비 3000원 입니다 \n']
# _
# q: ['아메리카노 두 잔 주문 할게요 \n']
# a: ['\t아메리카노 따뜻한 건가 요 \n']
# p: ['네 뜨거운 음료 로 드릴 까요 \n']
# _
# q: ['치즈 케이크 하나같이 주문 할게요 \n']
# a: ['\t네 아이스 아메리카노 두 잔 치즈 케이크 주문 받았습니다 \n']
# p: ['네 알겠습니다 \n']
# _
# q: ['저희 그냥 먹고 가겠습니다 \n']
# a: ['\t네 벨 울리면 가지러 와주세요 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['아이스 아메리카노 한 잔 이랑 스콘 하나 할게요 \n']
# a: ['\t드시고 가세 요 \n']
# p: ['10시 따뜻한 거 거 요 \n']
# _
# q: ['아니요 포장 이 요 \n']
# a: ['\t스콘 은 데워 드릴 까요 \n']
# p: ['네 담아 드립니다 \n']
# _
# q: ['네 부탁드릴게요 \n']
# a: ['\t더 필요한 건 없으신 가요 \n']
# p: ['네 어떤 거 로 드릴 까요 \n']
# _
# q: ['도장 찍어주세요 \n']
# a: ['\t네 이리 주세요 \n']
# p: ['네 저희 가게 마스코트 메뉴 에요 \n']
# _
# q: ['여기 카페인 안 들어간 게 있나요 \n']
# a: ['\t루이보스 랑 유자차 있어요 \n']
# p: ['쪽 랑 고르시면 됩니다 \n']
# _
# q: ['유자차 차갑게 주문 가능한가요 \n']
# a: ['\t유자차 는 안되고 루이보스 는 아이스 로 가능하세요 \n']
# p: ['네 500원 가능합니다 \n']
# _
# q: ['그럼 루이보스 차갑게 하나 랑 유자차 하나 할게요 \n']
# a: ['\t네 포인트 나 할인 카드 있으세요 \n']
# p: ['네 포인트 이 담아 은 있습니다 \n']
# _
# q: ['네 여기 kt 더블 할인 되죠 \n']
# a: ['\t할인 적용 해서 9300원 결제 도 와 드릴게요 \n']
# p: ['네 알겠습니다 \n']
# _
# q: ['네 여기 카드 있습니다 \n']
# a: ['\t여기 진동 벨 가지 고 계시다가 울리면 주문 한 음료 가져가세요 \n']
# p: ['네 카드 가능합니다 \n']
# _
# q: ['고구마 라테 아이스 도 되나요 \n']
# a: ['\t고구마 라테 는 따뜻하게만 돼요 \n']
# p: ['아뇨 매장 에서는 종류 만 사용 가능합니다 \n']
# _
# q: ['카페 와이파이 비밀번호 알 수 있을까요 \n']
# a: ['\tabc 123 입니다 \n']
# p: ['네 저희 가게 마스코트 메뉴 에요 \n']
# _
# q: ['쿠폰 몇 개 를 모으면 무료 로 아이스커피 를 마실 수 있어요 \n']
# a: ['\t쿠폰 10 개 를 모으면 무료 로 아이스 아메리카노 를 제공 하고 있어요 \n']
# p: ['네 가능합니다 \n']
# _
# q: ['카페 몇 시 까지 해 요 \n']
# a: ['\t오후 10시 까지 합니다 \n']
# p: ['10시 까지 합니다 \n']
# _
# q: ['오픈 이 몇 시 인가요 \n']
# a: ['\t9시 부터 열어요 \n']
# p: ['네 담아 드립니다 \n']
# _
# q: ['캐러멜 프라푸치노 주세요 \n']
# a: ['\t다른 사항 은 없으신 가요 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['휘핑크림 에 캐러멜 드리블 이랑 통 잡아 칩 깔아주세요 \n']
# a: ['\t다시 말씀 해주시겠어요 \n']
# p: ['네 알겠습니다 \n']
# _
# q: ['캐러멜 드리블 이랑 통 잡아 칩이요 \n']
# a: ['\t6700원 결제 도 와 드리겠습니다 \n']
# p: ['네 더 필요한 거 있으세요 \n']
# _
# q: ['아이스 아메리카노 랑 밀크 티 차가운 거 랑 치즈케이크 하나 주세요 \n']
# a: ['\t지금 치즈케이크 가 다 팔려서요 \n']
# p: ['네 더 필요한 것 가요 \n']
# _
# q: ['그럼 그 걸 로 할게요 \n']
# a: ['\t네 총 18000원 입니다 \n']
# p: ['네 저희 가게 거 거 요 \n']
# _
# q: ['네 먹고 갈게요 \n']
# a: ['\t유리잔 에 드릴게요 \n']
# p: ['네 어떤 거 로 드릴 까요 \n']
# _
# q: ['아메리카노 아이스 로 하나요 \n']
# a: ['\t사이즈 는 뭘 로 드릴 까요 \n']
# p: ['네 배달 비 마스코트 메뉴 에요 \n']
# _
# q: ['작은 사이즈 로 주세요 \n']
# a: ['\t추가 하시는 건 없으시고요 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['쿠키 도 주세요 \n']
# a: ['\t멤버십 있으신 가요 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['아뇨 그냥 주세요 \n']
# a: ['\t할인 카드 도 안 하시나요 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['할인 카드 는 드릴게요 \n']
# a: ['\t네 \n']
# p: ['아니요 한 가능합니다 \n']
# _
# q: ['아메리카노 하나요 \n']
# a: ['\t따뜻한 거 맞으세요 \n']
# p: ['네 배달 비 3000원 입니다 \n']
# _
# q: ['아니오 아이스 로 주세요 \n']
# a: ['\t네 저희 꺼 적립 카드 있으세요 \n']
# p: ['네 저희 음료 것 드리겠습니다 \n']
# _
# q: ['아니오 하나 만들어주세요 \n']
# a: ['\t네 여기 있습니다 \n']
# p: ['14 500원 입니다 \n']
# _
# q: ['카드 결제 할게요 \n']
# a: ['\t네 앞 에 카드 꽃 아 주시 면 됩니다 \n']
# p: ['네 카드 가능합니다 \n']
# _
# q: ['아메리카노 한잔 줘요 \n']
# a: ['\t따뜻한 걸 로 드릴 까요 \n']
# p: ['네 어떤 거 로 드릴 까요 \n']
# _
# q: ['이 날씨 에 차가운 거 먹어요 \n']
# a: ['\t따뜻한 아메리카노 한잔 준비 해드리겠습니다 \n']
# p: ['네 어떤 거 로 드릴 까요 \n']
# _
# q: ['아메리카노 2 잔 주세요 \n']
# a: ['\t따뜻한 거 로 드릴 까요 \n']
# p: ['네 어떤 거 로 드릴 까요 \n']
# _
# q: ['하나 는 따뜻한 거 하나 는 차가운 거 로 주세요 \n']
# a: ['\t드시고 가시나요 \n']
# p: ['네 사이즈 는 톨 사이즈 음료 괜찮으신 가요 \n']
# _
# q: ['조금 마시다가 갈 거 에요 \n']
# a: ['\t가실 때 말씀 해주시면 테이크 아웃 잔 에 드릴 테 니 우선 머그잔 에 드리겠습니다 \n']
# p: ['네 저희 가게 마스코트 메뉴 에요 \n']
# _
# q: ['여기 쿠폰 도장 찍어주세요 \n']
# a: ['\t2 개 찍어 드렸고 진동 벨 로 알려 드리겠습니다 \n']
# p: ['네 저희 가게 마스코트 메뉴 에요 \n']
# _
# q: ['그리고 미지근한 물 도 1 잔 만 부탁드려요 \n']
# a: ['\t같이 준비 해드리겠습니다 \n']
# p: ['네 배달 필요한 거 거 요 \n']
# _
# q: ['아이스 아메리카노 두 잔 이랑 말차 케이크 한 개 주세요 \n']
# a: ['\t포장 이신 가요 \n']
# p: ['네 뜨거운 음료 로 드릴 까요 \n']
# _
# q: ['아니요 먹고 갈 거 예요 \n']
# a: ['\t포크 는 몇 개 드릴 까요 \n']
# p: ['네 더 필요한 거 있으세요 \n']
# _
# q: ['두 개 주세요 \n']
# a: ['\t먹고 가시는 거 면 유리잔 괜찮으실까 요 \n']
# p: ['네 드시고 가시나요 \n']
# _
# q: ['얼마 안 있고 갈 건데 테이크 아웃 잔 에 주시 면 안 될까 요 \n']
# a: ['\t정책 상 불가능하고 나가실 때 말씀 해주시면 테이크아웃 잔 으로 바꿔 드릴 수 는 있습니다 \n']
# p: ['네 불가능하고 나가실 두 해주시면 테이크아웃 됩니다 \n']
# _
# q: ['유리잔 에 주세요 \n']
# a: ['\t네 계산 해드리겠습니다 \n']
# p: ['네 더 필요한 거 없으신 가요 \n']
# _
# q: ['아메리카노 샷 추가 로 주세요 \n']
# a: ['\t테이크아웃 인가요 \n']
# p: ['네 드시고 가시나요 \n']
# _
# q: ['네 여기 텀블러 에 담아주세요 \n']
# a: ['\t고객 님 텀블러 이용 하시면 500원 할인 됩니다 \n']
# p: ['네 같이 적립 해 드리겠습니다 \n']
# _
# q: ['시럽 은 어디 있나요 \n']
# a: ['\t고객 님 시럽 은 왼쪽 에 보시 면 있습니다 \n']
# p: ['아뇨 매장 가능합니다 \n']
# _
# q: ['크랜베리 스콘 두 개도 포장 해주세요 \n']
# a: ['\t고객 님 살짝 데워 드릴 까요 \n']
# p: ['네 주문 가능합니다 \n']
# _
# q: ['총 금액 알려주세요 \n']
# a: ['\t스콘 두 개 아메리카노 샷 추가 텀블러 할인 해서 9500 입니다 \n']
# p: ['네 가능합니다 \n']
# _
# q: ['그렇게 해주세요 \n']
# a: ['\t매장 에서 드시고 가세 요 \n']
# p: ['네 어떤 거 로 드릴 까요 \n']
# _
# q: ['매장 에서 먹고 갈 거 예요 \n']
# a: ['\t할인 카드 있으신 가요 \n']
# p: ['네 더 필요한 거 있으세요 \n']
# _
# q: ['음료 는 텀블러 에 담아주세요 \n']
# a: ['\t텀블러 할인 300원 같이 해드릴게요 \n']
# p: ['쪽 같이 가능하세요 \n']
# _
# q: ['네 감사합니다 \n']
# a: ['\t진동 벨 로 알려 드릴게요 \n']
# p: ['네 가능합니다 \n']
# _
# q: ['위 에 자리 있나요 \n']
# a: ['\t네 자리 있습니다']
# p: ['쪽 한 사이즈 로만 판매 하고 있습니다 \n']
